# %% [markdown]
# # CS 195: Natural Language Processing
# ## Markov Models
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ericmanley/s26-CS195NLP/blob/main/F2_3_MarkovModels.ipynb)

# %% [markdown]
# ## References
#
# Markov chain on Wikipedia: https://en.wikipedia.org/wiki/Markov_chain
#
# NLTK Book Chapter 2: Accessing Text Corpora and Lexical Resources https://www.nltk.org/book/ch02.html
#
# What is ChatGPT Doing and Why Does it Work? By Stephen Wolfram: https://writings.stephenwolfram.com/2023/02/what-is-chatgpt-doing-and-why-does-it-work/
# * This is a fascinating article that covers a lot of NLP topics. The opening motivates text generation with Markov-like descriptions.
#
# [Chapter 3: N-gram Language Models](https://web.stanford.edu/~jurafsky/slp3/3.pdf). *Speech and Language Processing.* Daniel Jurafsky & James H. Martin

# %%
#you shouldn't need to do this in Colab, but I had to do it on my own machine
#in order to connect to the nltk service
# import nltk
# import ssl

# try:
#     _create_unverified_https_context = ssl._create_unverified_context
# except AttributeError:
#     pass
# else:
#     ssl._create_default_https_context = _create_unverified_https_context

# %% [markdown]
# ## Andrey Andreyevich Markov
#
# <div>
# <img src="https://github.com/ericmanley/s26-CS195NLP/blob/main/images/Andrei_Markov.jpg?raw=1" width="200"/>
# </div>
#
# image source: https://en.wikipedia.org/wiki/Andrey_Markov

# %% [markdown]
# ## Markov Chain
#
# A **Markov Chain** describes a sequence of possible events and the probabilities of transitioning from one event state to another.
#
# It can be applied to text - what is the probability that one word follows another?
#
# Here is a diagram which corresponds to this text:
#
# `"I code when I am happy. I am happy therefore I code."`
#
# <div>
# <img src="https://github.com/ericmanley/s26-CS195NLP/blob/main/images/happy_markov_model.png?raw=1"/>
# </div>

# %% [markdown]
# ## Shakespeare Example
#
# *To be, or not to be, that is the question:
# Whether 'tis nobler in the mind to suffer
# The slings and arrows of outrageous fortune,
# Or to take Arms against a Sea of troubles*
#
# <div>
# <img src="https://github.com/ericmanley/s26-CS195NLP/blob/main/images/to_be_markov_model.png?raw=1"/>
# </div>
#
# Transitions here are shown as frequencies instead of probabilities.

# %% [markdown]
# ### Group Exercise
#
# Suppose you are trying to predict the next word after seeing this sequence: *"to be , or not to"*
#
# How can you use this model to predict the next word?

# %% [markdown]
# ## Demo: Let's see how we can construct the model for this text
#
# `"I code when I am happy. I am happy therefore I code."`

# %% [markdown]
# We want to represent this model in a data structure - could use 2D-list/matrix or a nested dictionary
#
# Nested dictionary representation
#
#
# `{
#  'I': {'am': 2, 'code': 2},
#  'code': {'.': 1, 'when': 1},
#  'when': {'I': 1}
#  'am': {'happy': 2},
#  'happy': {'.': 1, 'therefore': 1},
#  'therefore': {'I': 1},
#  '.': {'I': 1},
# }`

# %% [markdown]
# ## Digression: Let's talk about those dictionaries
#
#
# We could use a regular ol dictionary for this. But if you want to use a dictionary to count how many times you see a word, there's something that is kind of annoying about them:

# %%
regular_dict = {}

#...
# I saw "chicken", so let's add on to the "chicken" counter
regular_dict["chicken"] += 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1083945305.py in <cell line: 0>()
#       3 #...
#       4 # I saw "chicken", so let's add on to the "chicken" counter
# ----> 5 regular_dict["chicken"] += 1
#
# KeyError: 'chicken'

# %% [markdown]
# but it might not already be in the dictionary, so you have to do something like this:

# %%
if "chicken" in regular_dict:
    regular_dict["chicken"] += 1
else:
    regular_dict["chicken"] = 1

print(regular_dict["chicken"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1114851556.py in <cell line: 0>()
# ----> 1 if "chicken" in regular_dict:
#       2     regular_dict["chicken"] += 1
#       3 else:
#       4     regular_dict["chicken"] = 1
#       5
#
# NameError: name 'regular_dict' is not defined

# %% [markdown]
# It would be great if it just assumed a missing value was 0 instead of throwing an error!
#
# That's what a `defaultdict` does:

# %%
from collections import defaultdict

my_ddict = defaultdict(int) #we're going to put ints in there - this tells it to make 0 the default

my_ddict["chicken"] += 1

print(my_ddict["chicken"])
# Out:
# 1

# %% [markdown]
# 👍

# %% [markdown]
# ## Training a Markov Model
#
# Before we start training our model, let's make a list the **tokens** - all of the words, punctuation, and other things we want to be the states of the model.
#
# *(Future Warning: sometimes "tokens" can include parts of words, especially with LLMs - we'll discuss that later)*
#
# You can use the string `split` method for this:

# %%
text = "I code when I am happy . I am happy therefore I code . "
text_tokens = text.split()

word_tuples = list(zip(text_tokens,text_tokens[1:]))
print(word_tuples)

print(text_tokens)
# Out:
# [('I', 'code'), ('code', 'when'), ('when', 'I'), ('I', 'am'), ('am', 'happy'), ('happy', '.'), ('.', 'I'), ('I', 'am'), ('am', 'happy'), ('happy', 'therefore'), ('therefore', 'I'), ('I', 'code'), ('code', '.')]
# ['I', 'code', 'when', 'I', 'am', 'happy', '.', 'I', 'am', 'happy', 'therefore', 'I', 'code', '.']

# %% [markdown]
# Now let's build the model using this list

# %%
from collections import defaultdict
from pprint import pprint

# this is our dictionary of dictionaries -
# lambda: defaultdict(int) just means I want a bunch of defaultdicts of ints
transition_counts = defaultdict(lambda: defaultdict(int))


for idx in range(len(word_tuples) -1):
  current_token = word_tuples[idx][0]
  next_token = word_tuples[idx][1]
  transition_counts[current_token][next_token] += 1



pprint(transition_counts)
# Out:
# defaultdict(<function <lambda> at 0x7a4791f2a0c0>,
#             {'.': defaultdict(<class 'int'>, {'I': 1}),
#              'I': defaultdict(<class 'int'>, {'code': 2, 'am': 2}),
#              'am': defaultdict(<class 'int'>, {'happy': 2}),
#              'code': defaultdict(<class 'int'>, {'when': 1}),
#              'happy': defaultdict(<class 'int'>, {'.': 1, 'therefore': 1}),
#              'therefore': defaultdict(<class 'int'>, {'I': 1}),
#              'when': defaultdict(<class 'int'>, {'I': 1})})

# %% [markdown]
# ## Let's make this into a function
#
# I'll call the list of tokens **corpus** - which is another word for a body of text you use to train a model

# %%
def train_markov_model(corpus):
    # this is our dictionary of dictionaries -
    # lambda: defaultdict(int) just means I want a bunch of defaultdicts of ints
    transition_counts = defaultdict(lambda: defaultdict(int))

    for idx in range(len(corpus)-1):
        current_token = corpus[idx]
        next_token = corpus[idx+1]
        transition_counts[current_token][next_token] += 1

    return transition_counts

to_be = "To be , or not to be , that is the question : Whether 'tis nobler in the mind to suffer The slings and arrows of outrageous fortune , Or to take Arms against a Sea of troubles ,"
to_be_tokens = to_be.lower().split() #convert to lowercase and break apart by spaces into a list
to_be_model = train_markov_model(to_be_tokens)

pprint(to_be_model)
# Out:
# defaultdict(<function train_markov_model.<locals>.<lambda> at 0x7a4791e613a0>,
#             {"'tis": defaultdict(<class 'int'>, {'nobler': 1}),
#              ',': defaultdict(<class 'int'>, {'or': 2, 'that': 1}),
#              ':': defaultdict(<class 'int'>, {'whether': 1}),
#              'a': defaultdict(<class 'int'>, {'sea': 1}),
#              'against': defaultdict(<class 'int'>, {'a': 1}),
#              'and': defaultdict(<class 'int'>, {'arrows': 1}),
#              'arms': defaultdict(<class 'int'>, {'against': 1}),
#              'arrows': defaultdict(<class 'int'>, {'of': 1}),
#              'be': defaultdict(<class 'int'>, {',': 2}),
#              'fortune': defaultdict(<class 'int'>, {',': 1}),
#              'in': defaultdict(<class 'int'>, {'the': 1}),
#              'is': defaultdict(<class 'int'>, {'the': 1}),
#              'mind': defaultdict(<class 'int'>, {'to': 1}),
#              'nobler': defaultdict(<class 'int'>, {'in': 1}),
#              'not': defaultdict(<class 'int'>, {'to': 1}),
#              'of': defaultdict(<class 'int'>, {'outrageous': 1, 'troubles': 1}),
#              'or': defaultdict(<class 'int'>, {'not': 1, 'to': 1}),
#              'outrageous': defaultdict(<class 'int'>, {'fortune': 1}),
#              'question': defaultdict(<class 'int'>, {':': 1}),
#              'sea': defaultdict(<class 'int'>, {'of': 1}),
#              'slings': defaultdict(<class 'int'>, {'and': 1}),
#              'suffer': defaultdict(<class 'int'>, {'the': 1}),
#              'take': defaultdict(<class 'int'>, {'arms': 1}),
#              'that': defaultdict(<class 'int'>, {'is': 1}),
#              'the': defaultdict(<class 'int'>,
#                                 {'mind': 1,
#                                  'question': 1,
#                                  'slings': 1}),
#              'to': defaultdict(<class 'int'>,
#                                {'be': 2,
#                                 'suffer': 1,
#                                 'take': 1}),
#              'troubles': defaultdict(<class 'int'>, {',': 1}),
#              'whether': defaultdict(<class 'int'>, {"'tis": 1})})

# %% [markdown]
# ## How can we use this model?
#
# We could now make a prediction about the next word in a sequence - like predictive text keyboards
#
# <div>
# <img src="https://github.com/ericmanley/s26-CS195NLP/blob/main/images/predictive_text.png?raw=1"/ width=300>
# </div>

# %% [markdown]
# ### How can we generate a good random *next* word after "to"
#
# Notice this part of the model:
#
# `
# 'to': defaultdict(<class 'int'>,
#     {'be': 2,
#     'suffer': 1,
#     'take': 1}),
# `
#
# So when we see "to", we could
# * always predict "be"
# * randomly predict based on these possibilities
#     * generate a random int between 1 and 4
#         - 1: predict "be"
#         - 2: predict "be"
#         - 3: predict "suffer"
#         - 4: predict "take"
#     * words that appear after "to" more often a picked more often
#     * generates more interesting text than always picking the highest-ranked choice

# %% [markdown]
# ### coding it up

# %%
import random

def generate_random_next_word(current_word, transition_counts):
    #get the frequency of all words that come after current_word
    possible_words_counts = transition_counts[current_word]

    #count up the total of all words that come after current_word
    total_occurrences = sum(possible_words_counts.values())

    #we are going to select one occurence randomly
    random_num = random.randint(1,total_occurrences)

    #subtract words counts from our random number until we hit 0
    #this will hit more frequent words proportionally more often
    for word in possible_words_counts:
        random_num = random_num - possible_words_counts[word]
        if random_num <= 0:
            return word

print( generate_random_next_word("to",to_be_model)  )
print( generate_random_next_word("to",to_be_model)  )
print( generate_random_next_word("to",to_be_model)  )
print( generate_random_next_word("to",to_be_model)  )
print( generate_random_next_word("to",to_be_model)  )
print( generate_random_next_word("to",to_be_model)  )
print( generate_random_next_word("to",to_be_model)  )
print( generate_random_next_word("to",to_be_model)  )
print( generate_random_next_word("to",to_be_model)  )
print( generate_random_next_word("to",to_be_model)  )
# Out:
# suffer
# be
# be
# take
# be
# be
# be
# be
# be
# take

# %% [markdown]
# ## Generating a whole bunch of text
#
# Now we can write a function that successively calls `generate_random_next_word` to generate a whole sequence of words

# %%
def generate_text(num,start_word,model):
    #a running string to build on with random words
    markov_text = start_word + " "
    curr_word = start_word

    #add num random words onto our running string
    for n in range(num):
        curr_word = generate_random_next_word(curr_word,model)
        markov_text += curr_word
        markov_text += " "

    return markov_text

print( generate_text(30, "to", to_be_model) )
# Out:
# to be , that is the question : whether 'tis nobler in the mind to take arms against a sea of outrageous fortune , that is the question : whether 'tis

# %% [markdown]
# This text superficially looks like the training text, but it is nonsense.
#
# Two ways you can improve it:
# 1. Train it with more text
# 2. Use more than one word to predict the next word - needs to see lots of examples

# %% [markdown]
# ## Putting it all together

# %%
from nltk.corpus import gutenberg
from collections import defaultdict
import networkx as nx
import matplotlib.pyplot as plt
import random
from pprint import pformat

class MarkovModel:

    def __init__(self):
        # empty nested dictionary mapping words to words to ints
        self.transition_counts = defaultdict(lambda: defaultdict(int))

    def train(self,corpus):
        #loop through each word in the corpus record the next word
        #in its frequency dictionary
        for idx in range(len(corpus)-1):
            current_token = corpus[idx]
            next_token = corpus[idx+1]
            self.transition_counts[current_token][next_token] += 1

    def generate_random_next_word(self,current_word):
        #get the frequency of all words that come after current_word
        possible_words_counts = self.transition_counts[current_word]
        #count up the total of all words that come after current_word
        total_occurrences = sum(possible_words_counts.values())

        #we are going to select one occurence randomly
        random_num = random.randint(1,total_occurrences)

        #subtract words counts from our random number until we hit 0
        #this will hit more frequent words proportionally more often
        for word in possible_words_counts:
            random_num = random_num - possible_words_counts[word]
            if random_num <= 0:
                return word

    def generate_text(self,num=100,start_word = "I"):
        #a running string to build on with random words
        markov_text = start_word + " "
        curr_word = start_word

        #add num random words onto our running string
        for n in range(num):
            curr_word = self.generate_random_next_word(curr_word)
            markov_text += curr_word
            markov_text += " "

        return markov_text

    def __str__(self):
        # convert defaultdicts to dicts and format using the pprint formatter
        return pformat({key:dict(self.transition_counts[key]) for key in self.transition_counts})

    def visualize(self,probabilities=False,layout=nx.kamada_kawai_layout):
        # use this method to generate visualizations of small models
        # it will take too long on large texts - don't do it!
        G = nx.DiGraph()

        if probabilities:
            transition_probabilities = defaultdict(dict)
            for current_word, next_words in self.transition_counts.items():
                total_occurrences = sum(next_words.values())
                for next_word, count in next_words.items():
                    transition_probabilities[current_word][next_word] = count / total_occurrences

            for current_word, next_words in transition_probabilities.items():
                for next_word, probability in next_words.items():
                    G.add_edge(current_word, next_word, weight=probability)
        else:
            for current_word, next_words in self.transition_counts.items():
                for next_word, count in next_words.items():
                    G.add_edge(current_word, next_word, weight=count)

        pos = layout(G)
        edge_labels = {edge: f"{G.edges[edge]['weight']}" for edge in G.edges()}
        nx.draw(G, pos, with_labels=True, node_size=500, node_color='lightblue', font_size=10)
        nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

        plt.title("Markov Model Visualization")
        plt.show()

to_be = "To be , or not to be , that is the question : Whether 'tis nobler in the mind to suffer The slings and arrows of outrageous fortune , Or to take Arms against a Sea of troubles"
to_be_tokens = to_be.lower().split() #convert to lowercase and break apart by spaces into a list
to_be_model = MarkovModel()
to_be_model.train(to_be_tokens)

print(to_be_model)
# Out:
# {"'tis": {'nobler': 1},
#  ',': {'or': 2, 'that': 1},
#  ':': {'whether': 1},
#  'a': {'sea': 1},
#  'against': {'a': 1},
#  'and': {'arrows': 1},
#  'arms': {'against': 1},
#  'arrows': {'of': 1},
#  'be': {',': 2},
#  'fortune': {',': 1},
#  'in': {'the': 1},
#  'is': {'the': 1},
#  'mind': {'to': 1},
#  'nobler': {'in': 1},
#  'not': {'to': 1},
#  'of': {'outrageous': 1, 'troubles': 1},
#  'or': {'not': 1, 'to': 1},
#  'outrageous': {'fortune': 1},
#  'question': {':': 1},
#  'sea': {'of': 1},
#  'slings': {'and': 1},
#  'suffer': {'the': 1},
#  'take': {'arms': 1},
#  'that': {'is': 1},
#  'the': {'mind': 1, 'question': 1, 'slings': 1},
#  'to': {'be': 2, 'suffer': 1, 'take': 1},
#  'whether': {"'tis": 1}}

# %% [markdown]
# ## Downloading a corpus from the `nltk` library
#
# `nltk` is the Natural Language Toolkit - lots of great corpora, algorithms, and other resources
#
# They have a sample of free books from [Project Gutenberg](https://www.gutenberg.org/)
#
# You can find a list of the available corpora here: https://www.nltk.org/nltk_data/

# %%
import nltk
nltk.download('gutenberg') # you probably only need to do this once
print( nltk.corpus.gutenberg.fileids() )
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']
# [nltk_data]   Unzipping corpora/gutenberg.zip.

# %% [markdown]
# Let's try Moby Dick

# %%
from nltk.corpus import gutenberg
moby_dick = gutenberg.words('shakespeare-hamlet.txt')
print(moby_dick)
# Out:
# ['[', 'Alice', "'", 's', 'Adventures', 'in', ...]

# %% [markdown]
# This will only print truncated output, but it's the whole book!
#
# This is a list of tokens - exactly what we need!

# %%
model = MarkovModel()
model.train(moby_dick)

print(str(model)[:10000] )
#print( model ) #uncomment to print the whole model
# Out:
# ['[', 'Alice', "'", 's', 'Adventures', 'in', ...]
# {('!', '"', 'William'): {'the': 1},
#  ('!', "'", 'Beautiful'): {'Soup': 1},
#  ('!', "'", 'How'): {'cheerfully': 1},
#  ('!', "'", 'I'): {'wonder': 1},
#  ('!', 'A', 'little'): {'bright': 1},
#  ('!', 'ALICE', "'"): {'S': 1},
#  ('!', 'Alice', 'opened'): {'the': 1},
#  ('!', 'Always', 'lay'): {'the': 1},
#  ('!', 'And', 'I'): {'declare': 1},
#  ('!', 'And', 'how'): {'odd': 1},
#  ('!', 'And', 'it'): {"'": 1},
#  ('!', 'And', 'oh'): {',': 1},
#  ('!', 'And', 'when'): {'I': 1},
#  ('!', 'And', 'yesterday'): {'things': 1},
#  ('!', 'As', 'for'): {'pulling': 1},
#  ('!', 'Beau', '--'): {'ootiful': 3},
#  ('!', 'Besides', ','): {'SHE': 1},
#  ('!', 'But', 'I'): {"'": 2},
#  ('!', 'Come', 'and'): {'help': 1},
#  ('!', 'Come', 'here'): {'directly': 1},
#  ('!', 'Digging', 'for'): {'apples': 1},
#  ('!', 'Do', 'come'): {'back': 1},
#  ('!', 'Do', 'you'): {'think': 2},
#  ('!', 'Don', "'"): {'t': 3},
#  ('!', 'Good', '-'): {'bye': 1},
#  ('!', 'Half', '-'): {'past': 1},
#  ('!', 'He', 'says'): {'it': 1},
#  ('!', 'Heads', 'below'): {"!'": 1},
#  ('!', 'How', 'I'): {'wonder': 1},
#  ('!', 'How', 'brave'): {'they': 1},
#  ('!', 'How', 'funny'): {'it': 1},
#  ('!', 'How', 'puzzling'): {'all': 1},
#  ('!', 'How', 'queer'): {'everything': 1},
#  ('!', 'However', ','): {'I': 1, 'everything': 1, 'the': 1},
#  ('!', 'Hush', "!'"): {'said': 1},
#  ('!', 'I', "'"): {'LL': 1, 'd': 1, 'll': 2, 'm': 2, 've': 1},
#  ('!', 'I', 'almost'): {'wish': 1},
#  ('!', 'I', 'am'): {'so': 1},
#  ('!', 'I', 'do'): {'wonder': 1},
#  ('!', 'I', 'must'): {'have': 1},
#  ('!', 'I', 'shall'): {'be': 2, 'never': 1},
#  ('!', 'I', 'suppose'): {'Dinah': 1},
#  ('!', 'I', 'think'): {'I': 1},
#  ('!', 'I', 'wish'): {'you': 2},
#  ('!', 'I', 'wonder'): {'if': 1},
#  ('!', 'I', 'wouldn'): {"'": 1},
#  ('!', 'If', 'they'): {'had': 1},
#  ('!', 'It', "'"): {'ll': 1, 's': 3},
#  ('!', 'It', 'means'): {'much': 1},
#  ('!', 'It', 'was'): {'as': 1},
#  ('!', 'Let', 'me'): {'see': 2},
#  ('!', 'Let', 'this'): {'be': 1},
#  ('!', 'Mary', 'Ann'): {"!'": 1},
#  ('!', 'Never', 'heard'): {'of': 1},
#  ('!', 'No', ','): {'I': 1, 'it': 1, 'no': 1},
#  ('!', 'No', 'accounting'): {'for': 1},
#  ('!', 'No', 'room'): {"!'": 1},
#  ('!', 'Off', "--'"): {"'": 1},
#  ('!', 'Off', 'with'): {'his': 2},
#  ('!', 'Oh', '!'): {'won': 1},
#  ('!', 'Oh', ','): {'I': 1, 'my': 1},
#  ('!', 'Oh', 'dear'): {'!': 2},
#  ('!', 'Oh', 'my'): {'dear': 1, 'fur': 1},
#  ('!', 'Our', 'family'): {'always': 1},
#  ('!', 'Pat', '!'): {'Where': 1},
#  ('!', 'Pinch', 'him'): {'!': 1},
#  ('!', 'Prizes', "!'"): {'Alice': 1},
#  ('!', 'Quick', ','): {'now': 1},
#  ('!', 'She', "'"): {'ll': 1},
#  ('!', 'She', 'was'): {'a': 1},
#  ('!', 'She', 'went'): {'on': 1},
#  ('!', 'Sing', 'her'): {'"': 1},
#  ('!', 'So', 'Bill'): {"'": 1},
#  ('!', 'Soo', '--'): {'oop': 2},
#  ('!', 'Soup', 'of'): {'the': 1},
#  ('!', 'Stop', 'this'): {'moment': 1},
#  ('!', 'Suppress', 'him'): {'!': 1},
#  ('!', 'Take', 'your'): {'choice': 1},
#  ('!', 'That', 'WILL'): {'be': 1},
#  ('!', 'The', 'Antipathies'): {',': 1},
#  ('!', 'The', 'Duchess'): {'!': 1},
#  ('!', 'The', 'Queen'): {"!'": 1},
#  ('!', 'The', 'adventures'): {'first': 1},
#  ('!', 'There', "'"): {'s': 1},
#  ('!', 'There', 'are'): {'no': 1},
#  ('!', 'There', 'ought'): {'to': 1},
#  ('!', 'They', 'are'): {'waiting': 1},
#  ('!', 'Turn', 'that'): {'Dormouse': 1},
#  ('!', 'Ugh', ','): {'Serpent': 1},
#  ('!', 'WHAT', 'are'): {'you': 1},
#  ('!', 'When', 'I'): {'used': 1},
#  ('!', 'Where', 'CAN'): {'I': 1},
#  ('!', 'Where', 'are'): {'you': 1},
#  ('!', 'Who', 'cares'): {'for': 1},
#  ('!', 'Who', 'ever'): {'saw': 1},
#  ('!', 'Who', 'for'): {'such': 1},
#  ('!', 'Why', ','): {'I': 2, 'she': 1, 'there': 1},
#  ('!', 'YOU', 'do'): {'it': 1},
#  ('!', 'You', "'"): {'re': 1},
#  ('!', 'You', 'see'): {',': 1, 'the': 1},
#  ('!', 'catch', 'hold'): {'of': 1},
#  ('!', 'down', 'she'): {'came': 1},
#  ('!', 'either', 'the'): {'locks': 1},
#  ('!', 'ever', 'so'): {'many': 1},
#  ('!', 'fetch', 'it'): {'here': 1},
#  ('!', 'it', 'was'): {'too': 1},
#  ('!', 'sh', "!'"): {'and': 1},
#  ('!', 'she', 'knows'): {'such': 1},
#  ('!', 'she', 'was'): {'up': 1},
#  ('!', 'that', 'accounts'): {'for': 1},
#  ('!', 'the', 'Duchess'): {',': 1},
#  ('!', 'the', 'little'): {'door': 1},
#  ('!', 'the', 'master'): {'says': 1},
#  ('!', 'then', 'yours'): {'wasn': 1},
#  ('!', 'they', "'"): {'ll': 1},
#  ('!', 'thump', '!'): {'down': 1},
#  ('!', 'when', 'she'): {'got': 1},
#  ('!', 'won', "'"): {'t': 1},
#  ('!', 'wow', '!'): {'wow': 2},
#  ('!', 'wow', "!'"): {"'": 1, 'While': 1},
#  ('!', 'you', 'may'): {'nurse': 1},
#  ('!"', '"', 'Coming'): {'in': 1},
#  ('!"', 'But', 'the'): {'snail': 1},
#  ('!"', 'I', 'shall'): {'only': 1},
#  ('!"', 'You', 'know'): {'the': 1},
#  ('!"', 'and', 'gave'): {'a': 1},
#  ('!"', 'here', ",'"): {'thought': 1},
#  ('!"\'', "'", 'How'): {'dreadfully': 1},
#  ('!"\'', "'", 'Somebody'): {'said': 1},
#  ('!"\'', "'", 'They'): {'were': 1},
#  ('!"?\'', 'the', 'Rabbit'): {'asked': 1},
#  ("!'", "'", 'Ah'): {',': 1},
#  ("!'", "'", 'And'): {'who': 2},
#  ("!'", "'", 'But'): {'I': 1},
#  ("!'", "'", 'Call'): {'the': 1},
#  ("!'", "'", 'Can'): {"'": 1},
#  ("!'", "'", 'Chorus'): {'again': 1},
#  ("!'", "'", 'Consider'): {'your': 1},
#  ("!'", "'", 'Digging'): {'for': 1},
#  ("!'", "'", 'Do'): {'as': 1},
#  ("!'", "'", 'Everybody'): {'says': 1},
#  ("!'", "'", 'Here'): {'!': 1},
#  ("!'", "'", 'Hold'): {'your': 2},
#  ("!'", "'", 'How'): {'do': 1},
#  ("!'", "'", 'I'): {"'": 3,
#                     '--': 1,
#                     'HAVE': 1,
#                     'can': 1,
#                     'couldn': 1,
#                     'didn': 1,
#                     'haven': 1,
#                     'shall': 1,
#                     'wish': 1,
#                     'won': 1},
#  ("!'", "'", 'It'): {"'": 1},
#  ("!'", "'", 'No'): {',': 1},
#  ("!'", "'", 'Oh'): {'!': 1, ',': 3},
#  ("!'", "'", 'Perhaps'): {'not': 1},
#  ("!'", "'", 'Read'): {'them': 1},
#  ("!'", "'", 'Serpent'): {',': 1},
#  ("!'", "'", 'So'): {'you': 1},
#  ("!'", "'", 'Sure'): {',': 1},
#  ("!'", "'", 'That'): {'is': 1},
#  ("!'", "'", 'What'): {'for': 1},
#  ("!'", "'", 'Why'): {'should': 1},
#  ("!'", "'", 'YOU'): {"'": 1},
#  ("!'", "'", 'Yes'): {',': 1},
#  ("!'", "'", 'You'): {"'": 1, 'ought': 1},
#  ("!'", '(', 'Alice'): {'thought': 1},
#  ("!'", '(', 'Dinah'): {'was': 1},
#  ("!'", '(', 'He'): {'pronounced': 1},
#  ("!'", '(', 'Sounds'): {'of': 1},
#  ("!'", '(', 'Which'): {'was': 1},
#  ("!'", '(', 'a'): {'loud': 1},
#  ("!'", '(', 'for'): {'when': 1},
#  ("!'", '(', 'when'): {'she': 1},
#  ("!'", "('", 'I'): {'only': 1},
#  ("!'", 'Alas', '!'): {'it': 1},
#  ("!'", 'Alice', 'began'): {'in': 1},
#  ("!'", 'Alice', 'called'): {'after': 1},
#  ("!'", 'Alice', 'felt'): {'so': 1},
#  ("!'", 'Alice', 'glanced'): {'rather': 1},
#  ("!'", 'Alice', 'had'): {'no': 1},
#  ("!'", 'Alice', 'replied'): {'in': 1},
#  ("!'", 'Alice', 'said'): {'to': 1, 'very': 1},
#  ("!'", 'Alice', 'thought'): {'to': 1},
#  ("!'", 'Alice', 'was'): {'beginning': 1, 'more': 1},
#  ("!'", 'Alice', 'watched'): {'the': 1},
#  ("!'", 'And', 'Alice'): {'was': 1},
#  ("!'", 'And', 'here'): {'poor': 1},
#  ("!'", 'And', 'she'): {'began': 2, 'opened': 1},
#  ("!'", 'And', 'so'): {'she': 1},
#  ("!'", 'And', 'the'): {'Eaglet': 1},
#  ("!'", 'And', 'they'): {'pinched': 1},
#  ("!'", 'And', 'with'): {'that': 1},
#  ("!'", 'As', 'she'): {'said': 2},
#  ("!'", 'At', 'this'): {'the': 1},
#  ("!'", 'But', 'she'): {'did': 1, 'went': 1},
#  ("!'", 'But', 'there'): {'seemed': 1},
#  ("!'", 'By', 'this'): {'time': 1},
#  ("!'", 'CHAPTER', 'VII'): {'.': 1},
#  ("!'", 'CHAPTER', 'XI'): {'.': 1},
#  ("!'", 'CHAPTER', 'XII'): {'Alice': 1},
#  ("!'", 'CHORUS', '.'): {"'": 1},
#  ("!'", 'For', 'some'): {'minutes': 1},
#  ("!'", 'For', 'the'): {'Mouse': 1},
#  ("!'", 'He', 'got'): {'behind': 1},
#  ("!'", 'It', 'did'): {'so': 1},
#  ("!'", 'Just', 'as'): {'she': 1},
#  ("!'", 'Just', 'then'): {'her': 1},
#  ("!'", 'Last', 'came'): {'a': 1},
#  ("!'", 'On', 'various'): {'pretexts': 1},
#  ("!'", 'She', 'ate'): {'a': 1},
#  ("!'", 'She', 'drew'): {'her': 1},
#  ("!'", 'She', 'generally'): {'gave': 1},
#  ("!'", 'She', 'had'): {'not': 1},
#  ("!'", 'She', 'said'): {'the': 1},
#  ("!'", 'She', 'waited'): {'for': 1},
#  ("!'", 'She', 'was'): {'close': 1, 'looking': 1},
#  ("!'", 'So', 'she'): {'began': 1},
#  ("!'", 'So', 'they'): {'went': 1},
#  ("!'", 'Soon', 'her'): {'eye': 1},
#  ("!'", 'The', 'Duchess'): {'took': 1},
#  ("!'", 'The', 'Footman'): {'seemed': 1},
#  ("!'", 'The', 'Knave'): {'did': 1},
#  ("!'", 'The', 'Mouse'): {'only': 1},
#  ("!'", 'The', 'Queen'): {'had': 1, 'turned': 1},
#  ("!'", 'The', 'first'): {'witness': 1},
#  ("!'", 'The', 'poor'): {'little': 1},
#  ("!'", 'Then', 'came'): {'a': 1},
#  ("!'", 'There', 'was'): {'a': 2},
#  ("!'", 'They', 'all'): {'sat': 1},
#  ("!'", 'They', 'had'): {'not': 1},
#  ("!'", 'This', 'sounded'): {'promising': 1},
#  ("!'", 'This', 'speech'): {'caused': 1},
#  ("!'", 'Those', 'whom'): {'she': 1},
#  ("!'", 'When', 'the'): {'Mouse': 1},
#  ("!'", 'While', 'the'): {'Duchess': 1},
#  ("!'", 'about', 'once'): {'in': 1},
#  ("!'", 'added', 'the'): {'Gryphon': 1},
#  ("!'", 'and', 'a'): {'Canary': 1},
#  ("!'", 'and', 'at'): {'last': 1},
#  ("!'", 'and', 'he'): {'went': 1},
#  ("!'", 'and', 'ran'): {'the': 1},
#  ("!'", 'and', 'read'): {'out': 1},
#  ("!'", 'and', 'she'): {'ran': 1},
#  ("!'", 'and', 'the'): {'Dormouse': 1, 'King': 1, 'procession': 1, 'three': 1},
#  ("!'", 'and', 'they'): {'all': 1},
#  ("!'", 'but', 'the'): {'Mouse': 1},
#  ("!'", 'cried', 'Alice'): {'(': 1, ',': 3, 'again': 1, 'hastily': 1, 'in': 1},
#  ("!'", 'cried', 'the'): {'Gryphon': 3, 'Mock': 2, 'Mouse': 3},
#  ("!'", 'exclaimed', 'Alice'): {',': 1, '.': 2},
#  ("!'", 'from', 'the'): {'Gryphon': 1},
#  ("!'", 'he', 'added'): {'looking': 1},
#  ("!'", 'he', 'replied'): {'.': 1},
#  ("!'", 'interrupted', 'Alice'): {'.': 1},
#  ("!'", 'it', 'exclaimed'): {'.': 1},
#  ("!'", 'on', 'their'): {'slates': 1},
#  ("!'", 'on', 'which'): {'the': 1},
#  ("!'", 'or', "'"): {'Off': 2},
#  ("!'", 'pleaded', 'Alice'): {'.': 1},
#  ("!'", 'pleaded', 'poor'): {'Alice': 2},
#  ("!'", 'repeated', 'the'): {'Pigeon': 1},
#  ("!'", 'roared', 'the'): {'Queen': 1},
#  ("!'", 'said', 'Alice'): {',': 9,
#                            '.': 3,
#                            ';': 1,
#                            'aloud': 1,
#                            'as': 1,
#                            '

# %%
print( model.generate_text(100,"to") )
# Out:
# to night Vnto that great amisse , ho , I cannot bee Players We are Companions noted and excuse . Ophe . She sounds to looke you , I your loue our deare Father ? Hor . Go seeke him demand of generall assault Reynol . Well : who not go , the watch , Her speech of vantage . But soft , did sting thy Blush ? Ham . Enter Queene . There ' Alarme , And by no such dexterity to our State , Ile ope my yong man . Beleeue me in excrements , That with a Scull

# %% [markdown]
# ## Group Exercise
#
# Load some additional books and train the model with more than one book
# * call `model.train` multiple times
#
# What kind of text does your model generate?

# %% [markdown]
# ## Group Exercise
#
# Check out the other examples of corpora here: https://www.nltk.org/book/ch02.html
#
# Can you train and generate other kinds of text?

# %% [markdown]
# ## Group Exercise
#
# So far, we've been working on a **bigram model** or **first order Markov Model** because we're using only one word to predict the next.
#
# What if we wanted a **trigram model** or **2nd-order Markov Model**? That is, a model where we predict the next word based on the two previous words?
#
# Sketch out what this data structure would look like
#
# For reference, here's what the 1st-order Markov Model data structure looks like:
#
# `"To be , or not to be , that is the question : Whether 'tis nobler in the mind to suffer The slings and arrows of outrageous fortune , Or to take Arms against a Sea of troubles"`
#
# `{"'tis": {'nobler': 1},
#  ',': {'or': 2, 'that': 1},
#  ':': {'whether': 1},
#  'a': {'sea': 1},
#  'against': {'a': 1},
#  'and': {'arrows': 1},
#  'arms': {'against': 1},
#  'arrows': {'of': 1},
#  'be': {',': 2},
#  'fortune': {',': 1},
#  'in': {'the': 1},
#  'is': {'the': 1},
#  'mind': {'to': 1},
#  'nobler': {'in': 1},
#  'not': {'to': 1},
#  'of': {'outrageous': 1, 'troubles': 1},
#  'or': {'not': 1, 'to': 1},
#  'outrageous': {'fortune': 1},
#  'question': {':': 1},
#  'sea': {'of': 1},
#  'slings': {'and': 1},
#  'suffer': {'the': 1},
#  'take': {'arms': 1},
#  'that': {'is': 1},
#  'the': {'mind': 1, 'question': 1, 'slings': 1},
#  'to': {'be': 2, 'suffer': 1, 'take': 1},
#  'whether': {"'tis": 1}}`

# %% [markdown]
# ## Applied Exploration
#
# Enhance the `MarkovModel` class to take in a parameter that allows it to be a 1st, 2nd, 3rd, etc. order model.
# * Train it with a large corpus (maybe more than one)
# * Give examples of the text generated at each order
# * Do you run into difficulties with some pairs not being present? How should we deal with those - write down some ideas.

# %% [markdown]
# ## 2nd Order MarkovModel
#
# I extended the original model by adding an order parameter so it can use multiple previous words instead of just one.each state was a single word mapping to the next word, but now the state can be a tuple of words (like ("to","be")) the code was updated updated to use these multi-word states, including a sliding window to move through the text as we talked about in class.

# %%
from nltk.corpus import gutenberg
from collections import defaultdict
import networkx as nx
import matplotlib.pyplot as plt
import random
from pprint import pformat

class MarkovModel:

    def __init__(self, order=2):
        # empty nested dictionary mapping words (or states) to words to ints
        self.order = order
        self.transition_counts = defaultdict(lambda: defaultdict(int))

    def train(self,corpus):
        #loop through each word in the corpus record the next word
        #in its frequency dictionary
        for idx in range(len(corpus)-self.order):

            # for order=1 this is just a single word (same as before)
            # for higher order this is a tuple of words
            if self.order == 1:
                current_token = corpus[idx]
            else:
                current_token = tuple(corpus[idx:idx+self.order])

            next_token = corpus[idx+self.order]
            self.transition_counts[current_token][next_token] += 1

    def generate_random_next_word(self,current_word):
        #get the frequency of all words that come after current_word
        possible_words_counts = self.transition_counts[current_word]

        #count up the total of all words that come after current_word
        total_occurrences = sum(possible_words_counts.values())
        if total_occurrences == 0:
            return None

        #we are going to select one occurence randomly
        random_num = random.randint(1,total_occurrences)

        #subtract words counts from our random number until we hit 0
        #this will hit more frequent words proportionally more often
        for word in possible_words_counts:
            random_num = random_num - possible_words_counts[word]
            if random_num <= 0:
                return word

    def generate_text(self,num=100,start_word = "I"):
        #a running string to build on with random words

        # handle starting state
        if self.order == 1:
            markov_text = start_word + " "
            curr_word = start_word
        else:
            # for higher order, start_word should be multiple words
            if isinstance(start_word, str):
                start_tokens = start_word.split()
            else:
                start_tokens = list(start_word)

            curr_word = tuple(start_tokens)
            markov_text = " ".join(start_tokens) + " "

        #add num random words onto our running string
        for n in range(num):
            next_word = self.generate_random_next_word(curr_word)
            if next_word is None:
                break

            markov_text += next_word
            markov_text += " "

            # update state
            if self.order == 1:
                curr_word = next_word
            else:
                curr_word = curr_word[1:] + (next_word,)

        return markov_text

    def __str__(self):
        # convert defaultdicts to dicts and format using the pprint formatter
        return pformat({key:dict(self.transition_counts[key]) for key in self.transition_counts})

    def visualize(self,probabilities=False,layout=nx.kamada_kawai_layout):
        # use this method to generate visualizations of small models
        # it will take too long on large texts - don't do it!
        G = nx.DiGraph()

        if probabilities:
            transition_probabilities = defaultdict(dict)
            for current_word, next_words in self.transition_counts.items():
                total_occurrences = sum(next_words.values())
                for next_word, count in next_words.items():
                    transition_probabilities[current_word][next_word] = count / total_occurrences

            for current_word, next_words in transition_probabilities.items():
                for next_word, probability in next_words.items():
                    G.add_edge(current_word, next_word, weight=probability)
        else:
            for current_word, next_words in self.transition_counts.items():
                for next_word, count in next_words.items():
                    G.add_edge(current_word, next_word, weight=count)

        pos = layout(G)
        edge_labels = {edge: f"{G.edges[edge]['weight']}" for edge in G.edges()}
        nx.draw(G, pos, with_labels=True, node_size=500, node_color='lightblue', font_size=10)
        nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

        plt.title("Markov Model Visualization")
        plt.show()

# %% [markdown]
# ## Example Using Shakespeare-Hamlet

# %%
from nltk.corpus import gutenberg
moby_dick = gutenberg.words('shakespeare-hamlet.txt')
print(moby_dick)

model = MarkovModel()
model.train(moby_dick)

print(str(model)[:10000] )
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Hamlet', 'by', ...]
# {('!', 'A'): {'beast': 1},
#  ('!', 'Gho'): {'.': 1},
#  ('!', 'Hor'): {'.': 1},
#  ('!', 'How'): {'?': 1, 'weary': 1},
#  ('!', 'My'): {'Tables': 1},
#  ('!', 'O'): {'where': 1},
#  ('!', 'Oh'): {'Earth': 1,
#                'Vengeance': 1,
#                'Villaine': 1,
#                'bosome': 1,
#                'limed': 1},
#  ('!', 'Pol'): {'.': 1},
#  ('!', 'Who'): {'?': 1},
#  ('!', 'dye'): {'two': 1},
#  ('!', 'how'): {'Noble': 1},
#  ('!', 'where'): {'is': 1},
#  ('&', 'Guild'): {'.': 1},
#  ('&', 'Hamlet'): {'.': 1},
#  ('&', 'Horatio'): {'.': 1},
#  ('&', 'Mar'): {'.': 1},
#  ('&', 'Queen'): {'.': 1},
#  ('&', 'Queene'): {'haue': 1},
#  ('&', 'cloath'): {'thee': 1},
#  ('&', 'don'): {"'": 1},
#  ('&', 'drowne'): {'him': 1},
#  ('&', 'dupt'): {'the': 1},
#  ('&', 'his'): {'load': 1},
#  ('&', 'likeliehood'): {'to': 1},
#  ('&', 'look'): {'pale': 1},
#  ('&', 'noise'): {':': 1},
#  ('&', 'prey'): {'on': 1},
#  ('&', 'remembrance'): {'fitted': 1},
#  ('&', 'shewes'): {'a': 1},
#  ('&', 'tell'): {'me': 1},
#  ('&', 'through'): {'the': 1},
#  ('&', 'thunders'): {'in': 1},
#  ('&', 'twenty'): {'years': 1},
#  ('&', 'vbique'): {'?': 1},
#  ('&', 'vnfold'): {'your': 1},
#  ('&', 'wife'): {'is': 1},
#  ('&', 'wonder'): {'Barn': 1},
#  ("'", 'Affaire'): {',': 1},
#  ("'", 'Alarme'): {',': 1},
#  ("'", 'Alarum'): {'of': 1},
#  ("'", 'Ambassadors'): {',': 1, 'from': 1, 'of': 1},
#  ("'", 'Ambassadours'): {'that': 1},
#  ("'", 'Ambitious'): {'Norwey': 1},
#  ("'", 'Associates'): {'tend': 1},
#  ("'", 'Ayre'): {':': 1, 'to': 1},
#  ("'", 'Capitol'): {':': 1},
#  ("'", 'Church'): {'Kin': 1},
#  ("'", 'Court'): {':': 1},
#  ("'", 'Gainst'): {'Fortunes': 1},
#  ("'", 'Garden'): {'for': 1},
#  ("'", 'Hyrcanian'): {'Beast': 1},
#  ("'", 'Masse'): {',': 1},
#  ("'", 'Nose'): {'?': 1},
#  ("'", 'Occasions'): {'of': 1},
#  ("'", 'Offenders'): {'scourge': 1},
#  ("'", 'Sun'): {'Queen': 1},
#  ("'", 'Throate'): {',': 1},
#  ("'", 'Tis'): {'Hamlets': 1,
#                 'a': 2,
#                 'as': 1,
#                 'bitter': 1,
#                 'briefe': 1,
#                 'dangerous': 1,
#                 'deepely': 1,
#                 'ee': 1,
#                 'gone': 2,
#                 'heauie': 1,
#                 'heere': 2,
#                 'meete': 1,
#                 'most': 1,
#                 'not': 1,
#                 'now': 2,
#                 'so': 1,
#                 'strange': 1,
#                 'sweet': 1,
#                 'too': 1,
#                 'true': 1,
#                 'vnmanly': 1,
#                 'well': 1},
#  ("'", 'Twere'): {'better': 1, 'good': 2, 'to': 1},
#  ("'", 'Twill'): {'not': 1},
#  ("'", 'Vniuersity'): {',': 1},
#  ("'", 'abilitie'): {'of': 1},
#  ("'", 'affliction'): {'of': 1},
#  ("'", 'are'): {'a': 1, 'welcome': 1},
#  ("'", 'art'): {'a': 1},
#  ("'", 'assay'): {'of': 1},
#  ("'", 'assume'): {'a': 1},
#  ("'", 'cold'): {'ground': 1},
#  ("'", 'd'): {'!': 1,
#               ',': 39,
#               '.': 8,
#               ':': 8,
#               ';': 3,
#               '?': 6,
#               'Almost': 1,
#               'But': 1,
#               'Compact': 1,
#               'Comrade': 1,
#               'Cup': 1,
#               'Euen': 1,
#               'Fingers': 1,
#               'Forme': 2,
#               'Guil': 1,
#               'Ham': 5,
#               'He': 1,
#               'I': 1,
#               'King': 1,
#               'Laer': 1,
#               'Laertes': 2,
#               'Lord': 2,
#               'Loue': 1,
#               'March': 1,
#               'Most': 1,
#               'Ophelia': 1,
#               'Shooes': 1,
#               'To': 3,
#               'Vnto': 1,
#               'With': 3,
#               'Your': 1,
#               'a': 3,
#               'about': 1,
#               'accord': 1,
#               'againe': 1,
#               'against': 1,
#               'all': 1,
#               'and': 4,
#               'as': 3,
#               'at': 1,
#               'away': 1,
#               'being': 1,
#               'bloud': 1,
#               'bones': 1,
#               'both': 1,
#               'breath': 1,
#               'by': 1,
#               'cause': 1,
#               'defeate': 1,
#               'eare': 1,
#               'euill': 1,
#               'for': 3,
#               'go': 1,
#               'he': 1,
#               'her': 1,
#               'him': 3,
#               'his': 4,
#               'i': 3,
#               'iade': 1,
#               'in': 3,
#               'into': 1,
#               'it': 7,
#               'lies': 1,
#               'like': 1,
#               'longer': 1,
#               'loue': 1,
#               'me': 5,
#               'most': 1,
#               'my': 4,
#               'not': 1,
#               'of': 3,
#               'off': 1,
#               'on': 3,
#               'otherwise': 1,
#               'out': 1,
#               'so': 1,
#               'stuck': 1,
#               'that': 1,
#               'the': 3,
#               'thee': 2,
#               'their': 2,
#               'them': 2,
#               'this': 1,
#               'thou': 1,
#               'thoughts': 1,
#               'thy': 1,
#               'time': 1,
#               'to': 10,
#               'too': 1,
#               'vp': 2,
#               'vpon': 1,
#               'with': 4,
#               'withall': 1,
#               'within': 1,
#               'you': 5,
#               'your': 1},
#  ("'", 'darkest'): {'night': 1},
#  ("'", 'de'): {'His': 1, 'fain': 1},
#  ("'", 'earth'): {',': 1, '?': 1, 'ere': 1},
#  ("'", 'effect'): {'of': 1},
#  ("'", 'election'): {'and': 1, 'lights': 1},
#  ("'", 'em'): {'?': 2},
#  ("'", 'ene'): {'heere': 1, 'so': 2, 'that': 1, 'with': 1},
#  ("'", 'expectansie'): {'and': 1},
#  ("'", 'expell'): {'the': 1},
#  ("'", 'expresse'): {'his': 1},
#  ("'", 'exterior'): {',': 1},
#  ("'", 'extrauagant'): {',': 1},
#  ("'", 'gainst'): {'Selfe': 1, 'my': 1, 'that': 1, 'the': 1},
#  ("'", 'ground'): {'so': 1},
#  ("'", 'grownd'): {',': 1},
#  ("'", 'haue'): {'seene': 1, 'strew': 1},
#  ("'", 'illume'): {'that': 1},
#  ("'", 'imperiall'): {'Ioyntresse': 1},
#  ("'", 'important'): {'acting': 1},
#  ("'", 'impression'): {',': 1},
#  ("'", 'incestuous'): {'pleasure': 1},
#  ("'", 'l'): {'Feast': 1,
#               'be': 1,
#               'call': 1,
#               'e': 1,
#               'follow': 1,
#               'ha': 1,
#               'haue': 1,
#               'heare': 1,
#               'keepe': 1,
#               'make': 1,
#               'not': 2,
#               'put': 2,
#               'read': 1,
#               'reueale': 1,
#               'shew': 1,
#               'shift': 1,
#               'tax': 1,
#               'teach': 1,
#               'tell': 1,
#               'tender': 1,
#               'wait': 1},
#  ("'", 'lt'): {'doe': 1, 'mouth': 1},
#  ("'", 'm'): {'lost': 1, 'sorry': 1, 'sure': 1},
#  ("'", 'ment'): {':': 1, 'for': 1, 'is': 1},
#  ("'", 'n'): {',': 2, 'so': 3},
#  ("'", 'nant'): {'And': 1},
#  ("'", 'ne'): {'at': 1, 'to': 1},
#  ("'", 'obseru'): {"'": 1},
#  ("'", 'offence'): {'?': 1, 'is': 1},
#  ("'", 'opposed'): {'may': 1},
#  ("'", 're'): {',': 2,
#                '-': 6,
#                'Offices': 1,
#                'The': 1,
#                'begun': 1,
#                'his': 3,
#                'me': 1,
#                'the': 3,
#                'top': 1,
#                'which': 1,
#                'whom': 1},
#  ("'", 'recame'): {'Fortinbras': 1},
#  ("'", 'red'): {'by': 1},
#  ("'", 'remaster'): {"'": 1},
#  ("'", 'rerule'): {'me': 1},
#  ("'", 'retooke'): {'in': 1},
#  ("'", 'reway'): {'a': 1},
#  ("'", 'right'): {';': 1, 'old': 1},
#  ("'", 'ring'): {'Art': 1, 'Politician': 1},
#  ("'", 's'): {'Aspect': 1,
#               'Fennell': 1,
#               'Gonzago': 1,
#               'Hamlet': 1,
#               'Hecuba': 1,
#               'Herod': 1,
#               'Mettle': 1,
#               'Polonius': 1,
#               'Rew': 1,
#               'Rosemary': 1,
#               'Rouse': 1,
#               'Villanous': 1,
#               'Westward': 1,
#               'a': 7,
#               'almost': 1,
#               'an': 2,
#               'another': 1,
#               'beene': 1,
#               'bene': 1,
#               'businesse': 1,
#               'but': 1,
#               'come': 1,
#               'dead': 2,
#               'drown': 1,
#               'estate': 1,
#               'eyes': 1,
#               'fat': 1,
#               'fine': 1,
#               'follow': 4,
#               'for': 3,
#               'further': 1,
#               'giuen': 1,
#               'goe': 1,
#               'going': 1,
#               'good': 1,
#               'growne': 1,
#               'haue': 1,
#               'he': 1,
#               'him': 1,
#               'his': 1,
#               'hope': 1,
#               'humble': 1,
#               'in': 1,
#               'indeed': 1,
#               'it': 2,
#               'laid': 1,
#               'like': 1,
#               'loued': 1,
#               'mad': 1,
#               'matters': 1,
#               'mine': 1,
#               'my': 4,
#               'neere': 1,
#               'nere': 1,
#               'no': 4,
#               'not': 4,
#               'ought': 1,
#               'owne': 1,
#               'past': 1,
#               'put': 1,
#               'so': 1,
#               'some': 1,
#               'something': 1,
#               'such': 1,
#               'teares': 1,
#               'that': 1,
#               'the': 12,
#               'there': 2,
#               'this': 3,
#               'time': 1,
#               'to': 2,
#               'tongue': 1,
#               'too': 1,
#               'trickes': 1,
#               'two': 2,
#               'very': 1,
#               'vntimely': 1,
#               'wag': 1,
#               'wife': 1,
#               'withdraw': 1,
#               'wrong': 1,
#               'yet': 1,
#               'your': 1},
#  ("'", 'sere'): {':': 1},
#  ("'", 'st'): {"'": 1,
#                ',': 1,
#                '.': 1,
#                'already': 1,
#                'euer': 1,
#                'haue': 1,
#                'in': 1,
#                'mine': 1,
#                'not': 1,
#                'our': 1,
#                'perceiue': 1,
#                'perswade': 1,
#                'ranke': 1,
#                'she': 1,
#                'that': 1,
#                'this': 2,
#                'thou': 9,
#                'to': 1,
#                'wag': 1,
#                'worke': 1},
#  ("'", 't'): {

# %%
print( model.generate_text(100,"to be") )
# Out:
# to be made , for such a one , in fearing to be free , Art more ingag ' d vp ? King . Dead Qu . For looke you mock him not . Enter Ophelia . Polon . The other Motiue , Why to a peace Kin . Hee comes to tell vs this Ham . Marry this is Counter you false Danish Dogges . Noise within . What , frighted with false fire Qu . ' Tis as easie as lying : gouerne these Ventiges with your best violence , I had forgot : ' Tis now the time for

# %% [markdown]
# Visualization

# %% [markdown]
# #using small chunck

# %%
from nltk.corpus import gutenberg
import random

hamlet_tokens = [t.lower() for t in gutenberg.words('shakespeare-hamlet.txt')]

window = 30
start = random.randint(0, len(hamlet_tokens) - window)
small_tokens = hamlet_tokens[start:start + window]

model2 = MarkovModel(order=2)
model2.train(small_tokens)

print("Start index:", start)
model2.visualize(probabilities=False)
# Out:
# Start index: 16262

# %% [markdown]
# ## 3rd Order MarkovModel

# %%
from nltk.corpus import gutenberg
from collections import defaultdict
import networkx as nx
import matplotlib.pyplot as plt
import random
from pprint import pformat

class MarkovModel:

    def __init__(self, order=3):
        # empty nested dictionary mapping words (or states) to words to ints
        self.order = order
        self.transition_counts = defaultdict(lambda: defaultdict(int))

    def train(self,corpus):
        #loop through each word in the corpus record the next word
        #in its frequency dictionary
        for idx in range(len(corpus)-self.order):

            # for order=1 this is just a single word (same as before)
            # for higher order this is a tuple of words
            if self.order == 1:
                current_token = corpus[idx]
            else:
                current_token = tuple(corpus[idx:idx+self.order])

            next_token = corpus[idx+self.order]
            self.transition_counts[current_token][next_token] += 1

    def generate_random_next_word(self,current_word):
        #get the frequency of all words that come after current_word
        possible_words_counts = self.transition_counts[current_word]

        #count up the total of all words that come after current_word
        total_occurrences = sum(possible_words_counts.values())
        if total_occurrences == 0:
            return None

        #we are going to select one occurence randomly
        random_num = random.randint(1,total_occurrences)

        #subtract words counts from our random number until we hit 0
        #this will hit more frequent words proportionally more often
        for word in possible_words_counts:
            random_num = random_num - possible_words_counts[word]
            if random_num <= 0:
                return word

    def generate_text(self,num=100,start_word = "I"):
        #a running string to build on with random words

        # handle starting state
        if self.order == 1:
            markov_text = start_word + " "
            curr_word = start_word
        else:
            # for higher order, start_word should be multiple words
            if isinstance(start_word, str):
                start_tokens = start_word.split()
            else:
                start_tokens = list(start_word)

            curr_word = tuple(start_tokens)
            markov_text = " ".join(start_tokens) + " "

        #add num random words onto our running string
        for n in range(num):
            next_word = self.generate_random_next_word(curr_word)
            if next_word is None:
                break

            markov_text += next_word
            markov_text += " "

            # update state
            if self.order == 1:
                curr_word = next_word
            else:
                curr_word = curr_word[1:] + (next_word,)

        return markov_text

    def __str__(self):
        # convert defaultdicts to dicts and format using the pprint formatter
        return pformat({key:dict(self.transition_counts[key]) for key in self.transition_counts})

    def visualize(self,probabilities=False,layout=nx.kamada_kawai_layout):
        # use this method to generate visualizations of small models
        # it will take too long on large texts - don't do it!
        G = nx.DiGraph()

        if probabilities:
            transition_probabilities = defaultdict(dict)
            for current_word, next_words in self.transition_counts.items():
                total_occurrences = sum(next_words.values())
                for next_word, count in next_words.items():
                    transition_probabilities[current_word][next_word] = count / total_occurrences

            for current_word, next_words in transition_probabilities.items():
                for next_word, probability in next_words.items():
                    G.add_edge(current_word, next_word, weight=probability)
        else:
            for current_word, next_words in self.transition_counts.items():
                for next_word, count in next_words.items():
                    G.add_edge(current_word, next_word, weight=count)

        pos = layout(G)
        edge_labels = {edge: f"{G.edges[edge]['weight']}" for edge in G.edges()}
        nx.draw(G, pos, with_labels=True, node_size=500, node_color='lightblue', font_size=10)
        nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

        plt.title("Markov Model Visualization")
        plt.show()

# %% [markdown]
# ## Alice

# %%
from nltk.corpus import gutenberg
Alice_adventures = gutenberg.words('carroll-alice.txt')
print(Alice_adventures)

model = MarkovModel()
model.train(Alice_adventures)

print(str(model)[:50000] )
#print( model ) #uncomment to print the whole model
# Out:
# ['[', 'Alice', "'", 's', 'Adventures', 'in', ...]
# {('!', '"', 'William'): {'the': 1},
#  ('!', "'", 'Beautiful'): {'Soup': 1},
#  ('!', "'", 'How'): {'cheerfully': 1},
#  ('!', "'", 'I'): {'wonder': 1},
#  ('!', 'A', 'little'): {'bright': 1},
#  ('!', 'ALICE', "'"): {'S': 1},
#  ('!', 'Alice', 'opened'): {'the': 1},
#  ('!', 'Always', 'lay'): {'the': 1},
#  ('!', 'And', 'I'): {'declare': 1},
#  ('!', 'And', 'how'): {'odd': 1},
#  ('!', 'And', 'it'): {"'": 1},
#  ('!', 'And', 'oh'): {',': 1},
#  ('!', 'And', 'when'): {'I': 1},
#  ('!', 'And', 'yesterday'): {'things': 1},
#  ('!', 'As', 'for'): {'pulling': 1},
#  ('!', 'Beau', '--'): {'ootiful': 3},
#  ('!', 'Besides', ','): {'SHE': 1},
#  ('!', 'But', 'I'): {"'": 2},
#  ('!', 'Come', 'and'): {'help': 1},
#  ('!', 'Come', 'here'): {'directly': 1},
#  ('!', 'Digging', 'for'): {'apples': 1},
#  ('!', 'Do', 'come'): {'back': 1},
#  ('!', 'Do', 'you'): {'think': 2},
#  ('!', 'Don', "'"): {'t': 3},
#  ('!', 'Good', '-'): {'bye': 1},
#  ('!', 'Half', '-'): {'past': 1},
#  ('!', 'He', 'says'): {'it': 1},
#  ('!', 'Heads', 'below'): {"!'": 1},
#  ('!', 'How', 'I'): {'wonder': 1},
#  ('!', 'How', 'brave'): {'they': 1},
#  ('!', 'How', 'funny'): {'it': 1},
#  ('!', 'How', 'puzzling'): {'all': 1},
#  ('!', 'How', 'queer'): {'everything': 1},
#  ('!', 'However', ','): {'I': 1, 'everything': 1, 'the': 1},
#  ('!', 'Hush', "!'"): {'said': 1},
#  ('!', 'I', "'"): {'LL': 1, 'd': 1, 'll': 2, 'm': 2, 've': 1},
#  ('!', 'I', 'almost'): {'wish': 1},
#  ('!', 'I', 'am'): {'so': 1},
#  ('!', 'I', 'do'): {'wonder': 1},
#  ('!', 'I', 'must'): {'have': 1},
#  ('!', 'I', 'shall'): {'be': 2, 'never': 1},
#  ('!', 'I', 'suppose'): {'Dinah': 1},
#  ('!', 'I', 'think'): {'I': 1},
#  ('!', 'I', 'wish'): {'you': 2},
#  ('!', 'I', 'wonder'): {'if': 1},
#  ('!', 'I', 'wouldn'): {"'": 1},
#  ('!', 'If', 'they'): {'had': 1},
#  ('!', 'It', "'"): {'ll': 1, 's': 3},
#  ('!', 'It', 'means'): {'much': 1},
#  ('!', 'It', 'was'): {'as': 1},
#  ('!', 'Let', 'me'): {'see': 2},
#  ('!', 'Let', 'this'): {'be': 1},
#  ('!', 'Mary', 'Ann'): {"!'": 1},
#  ('!', 'Never', 'heard'): {'of': 1},
#  ('!', 'No', ','): {'I': 1, 'it': 1, 'no': 1},
#  ('!', 'No', 'accounting'): {'for': 1},
#  ('!', 'No', 'room'): {"!'": 1},
#  ('!', 'Off', "--'"): {"'": 1},
#  ('!', 'Off', 'with'): {'his': 2},
#  ('!', 'Oh', '!'): {'won': 1},
#  ('!', 'Oh', ','): {'I': 1, 'my': 1},
#  ('!', 'Oh', 'dear'): {'!': 2},
#  ('!', 'Oh', 'my'): {'dear': 1, 'fur': 1},
#  ('!', 'Our', 'family'): {'always': 1},
#  ('!', 'Pat', '!'): {'Where': 1},
#  ('!', 'Pinch', 'him'): {'!': 1},
#  ('!', 'Prizes', "!'"): {'Alice': 1},
#  ('!', 'Quick', ','): {'now': 1},
#  ('!', 'She', "'"): {'ll': 1},
#  ('!', 'She', 'was'): {'a': 1},
#  ('!', 'She', 'went'): {'on': 1},
#  ('!', 'Sing', 'her'): {'"': 1},
#  ('!', 'So', 'Bill'): {"'": 1},
#  ('!', 'Soo', '--'): {'oop': 2},
#  ('!', 'Soup', 'of'): {'the': 1},
#  ('!', 'Stop', 'this'): {'moment': 1},
#  ('!', 'Suppress', 'him'): {'!': 1},
#  ('!', 'Take', 'your'): {'choice': 1},
#  ('!', 'That', 'WILL'): {'be': 1},
#  ('!', 'The', 'Antipathies'): {',': 1},
#  ('!', 'The', 'Duchess'): {'!': 1},
#  ('!', 'The', 'Queen'): {"!'": 1},
#  ('!', 'The', 'adventures'): {'first': 1},
#  ('!', 'There', "'"): {'s': 1},
#  ('!', 'There', 'are'): {'no': 1},
#  ('!', 'There', 'ought'): {'to': 1},
#  ('!', 'They', 'are'): {'waiting': 1},
#  ('!', 'Turn', 'that'): {'Dormouse': 1},
#  ('!', 'Ugh', ','): {'Serpent': 1},
#  ('!', 'WHAT', 'are'): {'you': 1},
#  ('!', 'When', 'I'): {'used': 1},
#  ('!', 'Where', 'CAN'): {'I': 1},
#  ('!', 'Where', 'are'): {'you': 1},
#  ('!', 'Who', 'cares'): {'for': 1},
#  ('!', 'Who', 'ever'): {'saw': 1},
#  ('!', 'Who', 'for'): {'such': 1},
#  ('!', 'Why', ','): {'I': 2, 'she': 1, 'there': 1},
#  ('!', 'YOU', 'do'): {'it': 1},
#  ('!', 'You', "'"): {'re': 1},
#  ('!', 'You', 'see'): {',': 1, 'the': 1},
#  ('!', 'catch', 'hold'): {'of': 1},
#  ('!', 'down', 'she'): {'came': 1},
#  ('!', 'either', 'the'): {'locks': 1},
#  ('!', 'ever', 'so'): {'many': 1},
#  ('!', 'fetch', 'it'): {'here': 1},
#  ('!', 'it', 'was'): {'too': 1},
#  ('!', 'sh', "!'"): {'and': 1},
#  ('!', 'she', 'knows'): {'such': 1},
#  ('!', 'she', 'was'): {'up': 1},
#  ('!', 'that', 'accounts'): {'for': 1},
#  ('!', 'the', 'Duchess'): {',': 1},
#  ('!', 'the', 'little'): {'door': 1},
#  ('!', 'the', 'master'): {'says': 1},
#  ('!', 'then', 'yours'): {'wasn': 1},
#  ('!', 'they', "'"): {'ll': 1},
#  ('!', 'thump', '!'): {'down': 1},
#  ('!', 'when', 'she'): {'got': 1},
#  ('!', 'won', "'"): {'t': 1},
#  ('!', 'wow', '!'): {'wow': 2},
#  ('!', 'wow', "!'"): {"'": 1, 'While': 1},
#  ('!', 'you', 'may'): {'nurse': 1},
#  ('!"', '"', 'Coming'): {'in': 1},
#  ('!"', 'But', 'the'): {'snail': 1},
#  ('!"', 'I', 'shall'): {'only': 1},
#  ('!"', 'You', 'know'): {'the': 1},
#  ('!"', 'and', 'gave'): {'a': 1},
#  ('!"', 'here', ",'"): {'thought': 1},
#  ('!"\'', "'", 'How'): {'dreadfully': 1},
#  ('!"\'', "'", 'Somebody'): {'said': 1},
#  ('!"\'', "'", 'They'): {'were': 1},
#  ('!"?\'', 'the', 'Rabbit'): {'asked': 1},
#  ("!'", "'", 'Ah'): {',': 1},
#  ("!'", "'", 'And'): {'who': 2},
#  ("!'", "'", 'But'): {'I': 1},
#  ("!'", "'", 'Call'): {'the': 1},
#  ("!'", "'", 'Can'): {"'": 1},
#  ("!'", "'", 'Chorus'): {'again': 1},
#  ("!'", "'", 'Consider'): {'your': 1},
#  ("!'", "'", 'Digging'): {'for': 1},
#  ("!'", "'", 'Do'): {'as': 1},
#  ("!'", "'", 'Everybody'): {'says': 1},
#  ("!'", "'", 'Here'): {'!': 1},
#  ("!'", "'", 'Hold'): {'your': 2},
#  ("!'", "'", 'How'): {'do': 1},
#  ("!'", "'", 'I'): {"'": 3,
#                     '--': 1,
#                     'HAVE': 1,
#                     'can': 1,
#                     'couldn': 1,
#                     'didn': 1,
#                     'haven': 1,
#                     'shall': 1,
#                     'wish': 1,
#                     'won': 1},
#  ("!'", "'", 'It'): {"'": 1},
#  ("!'", "'", 'No'): {',': 1},
#  ("!'", "'", 'Oh'): {'!': 1, ',': 3},
#  ("!'", "'", 'Perhaps'): {'not': 1},
#  ("!'", "'", 'Read'): {'them': 1},
#  ("!'", "'", 'Serpent'): {',': 1},
#  ("!'", "'", 'So'): {'you': 1},
#  ("!'", "'", 'Sure'): {',': 1},
#  ("!'", "'", 'That'): {'is': 1},
#  ("!'", "'", 'What'): {'for': 1},
#  ("!'", "'", 'Why'): {'should': 1},
#  ("!'", "'", 'YOU'): {"'": 1},
#  ("!'", "'", 'Yes'): {',': 1},
#  ("!'", "'", 'You'): {"'": 1, 'ought': 1},
#  ("!'", '(', 'Alice'): {'thought': 1},
#  ("!'", '(', 'Dinah'): {'was': 1},
#  ("!'", '(', 'He'): {'pronounced': 1},
#  ("!'", '(', 'Sounds'): {'of': 1},
#  ("!'", '(', 'Which'): {'was': 1},
#  ("!'", '(', 'a'): {'loud': 1},
#  ("!'", '(', 'for'): {'when': 1},
#  ("!'", '(', 'when'): {'she': 1},
#  ("!'", "('", 'I'): {'only': 1},
#  ("!'", 'Alas', '!'): {'it': 1},
#  ("!'", 'Alice', 'began'): {'in': 1},
#  ("!'", 'Alice', 'called'): {'after': 1},
#  ("!'", 'Alice', 'felt'): {'so': 1},
#  ("!'", 'Alice', 'glanced'): {'rather': 1},
#  ("!'", 'Alice', 'had'): {'no': 1},
#  ("!'", 'Alice', 'replied'): {'in': 1},
#  ("!'", 'Alice', 'said'): {'to': 1, 'very': 1},
#  ("!'", 'Alice', 'thought'): {'to': 1},
#  ("!'", 'Alice', 'was'): {'beginning': 1, 'more': 1},
#  ("!'", 'Alice', 'watched'): {'the': 1},
#  ("!'", 'And', 'Alice'): {'was': 1},
#  ("!'", 'And', 'here'): {'poor': 1},
#  ("!'", 'And', 'she'): {'began': 2, 'opened': 1},
#  ("!'", 'And', 'so'): {'she': 1},
#  ("!'", 'And', 'the'): {'Eaglet': 1},
#  ("!'", 'And', 'they'): {'pinched': 1},
#  ("!'", 'And', 'with'): {'that': 1},
#  ("!'", 'As', 'she'): {'said': 2},
#  ("!'", 'At', 'this'): {'the': 1},
#  ("!'", 'But', 'she'): {'did': 1, 'went': 1},
#  ("!'", 'But', 'there'): {'seemed': 1},
#  ("!'", 'By', 'this'): {'time': 1},
#  ("!'", 'CHAPTER', 'VII'): {'.': 1},
#  ("!'", 'CHAPTER', 'XI'): {'.': 1},
#  ("!'", 'CHAPTER', 'XII'): {'Alice': 1},
#  ("!'", 'CHORUS', '.'): {"'": 1},
#  ("!'", 'For', 'some'): {'minutes': 1},
#  ("!'", 'For', 'the'): {'Mouse': 1},
#  ("!'", 'He', 'got'): {'behind': 1},
#  ("!'", 'It', 'did'): {'so': 1},
#  ("!'", 'Just', 'as'): {'she': 1},
#  ("!'", 'Just', 'then'): {'her': 1},
#  ("!'", 'Last', 'came'): {'a': 1},
#  ("!'", 'On', 'various'): {'pretexts': 1},
#  ("!'", 'She', 'ate'): {'a': 1},
#  ("!'", 'She', 'drew'): {'her': 1},
#  ("!'", 'She', 'generally'): {'gave': 1},
#  ("!'", 'She', 'had'): {'not': 1},
#  ("!'", 'She', 'said'): {'the': 1},
#  ("!'", 'She', 'waited'): {'for': 1},
#  ("!'", 'She', 'was'): {'close': 1, 'looking': 1},
#  ("!'", 'So', 'she'): {'began': 1},
#  ("!'", 'So', 'they'): {'went': 1},
#  ("!'", 'Soon', 'her'): {'eye': 1},
#  ("!'", 'The', 'Duchess'): {'took': 1},
#  ("!'", 'The', 'Footman'): {'seemed': 1},
#  ("!'", 'The', 'Knave'): {'did': 1},
#  ("!'", 'The', 'Mouse'): {'only': 1},
#  ("!'", 'The', 'Queen'): {'had': 1, 'turned': 1},
#  ("!'", 'The', 'first'): {'witness': 1},
#  ("!'", 'The', 'poor'): {'little': 1},
#  ("!'", 'Then', 'came'): {'a': 1},
#  ("!'", 'There', 'was'): {'a': 2},
#  ("!'", 'They', 'all'): {'sat': 1},
#  ("!'", 'They', 'had'): {'not': 1},
#  ("!'", 'This', 'sounded'): {'promising': 1},
#  ("!'", 'This', 'speech'): {'caused': 1},
#  ("!'", 'Those', 'whom'): {'she': 1},
#  ("!'", 'When', 'the'): {'Mouse': 1},
#  ("!'", 'While', 'the'): {'Duchess': 1},
#  ("!'", 'about', 'once'): {'in': 1},
#  ("!'", 'added', 'the'): {'Gryphon': 1},
#  ("!'", 'and', 'a'): {'Canary': 1},
#  ("!'", 'and', 'at'): {'last': 1},
#  ("!'", 'and', 'he'): {'went': 1},
#  ("!'", 'and', 'ran'): {'the': 1},
#  ("!'", 'and', 'read'): {'out': 1},
#  ("!'", 'and', 'she'): {'ran': 1},
#  ("!'", 'and', 'the'): {'Dormouse': 1, 'King': 1, 'procession': 1, 'three': 1},
#  ("!'", 'and', 'they'): {'all': 1},
#  ("!'", 'but', 'the'): {'Mouse': 1},
#  ("!'", 'cried', 'Alice'): {'(': 1, ',': 3, 'again': 1, 'hastily': 1, 'in': 1},
#  ("!'", 'cried', 'the'): {'Gryphon': 3, 'Mock': 2, 'Mouse': 3},
#  ("!'", 'exclaimed', 'Alice'): {',': 1, '.': 2},
#  ("!'", 'from', 'the'): {'Gryphon': 1},
#  ("!'", 'he', 'added'): {'looking': 1},
#  ("!'", 'he', 'replied'): {'.': 1},
#  ("!'", 'interrupted', 'Alice'): {'.': 1},
#  ("!'", 'it', 'exclaimed'): {'.': 1},
#  ("!'", 'on', 'their'): {'slates': 1},
#  ("!'", 'on', 'which'): {'the': 1},
#  ("!'", 'or', "'"): {'Off': 2},
#  ("!'", 'pleaded', 'Alice'): {'.': 1},
#  ("!'", 'pleaded', 'poor'): {'Alice': 2},
#  ("!'", 'repeated', 'the'): {'Pigeon': 1},
#  ("!'", 'roared', 'the'): {'Queen': 1},
#  ("!'", 'said', 'Alice'): {',': 9,
#                            '.': 3,
#                            ';': 1,
#                            'aloud': 1,
#                            'as': 1,
#                            'in': 1,
#                            'indignantly': 3,
#                            'loudly': 1,
#                            'to': 1},
#  ("!'", 'said', 'Five'): {',': 1, '.': 1},
#  ("!'", 'said', 'Seven'): {'.': 1},
#  ("!'", 'said', 'a'): {'timid': 1},
#  ("!'", 'said', 'her'): {'sister': 1},
#  ("!'", 'said', 'the'): {'Caterpillar': 2,
#                          'Dormouse': 1,
#                          'Duchess': 3,
#                          'Eaglet': 1,
#                          'Gryphon': 1,
#                          'Hatter': 2,
#                          'King': 5,
#                          'Lory': 2,
#                          'March': 2,
#                          'Mock': 1,
#                          'Mouse': 4,
#                          'Pigeon': 2,
#                          'Queen': 7,
#                          'Rabbit': 3,
#                          'others': 1,
#                          'voice': 1,
#                          'young': 1},
#  ("!'", 'screamed', 'the'): {'Gryphon': 1, 'Pigeon': 1, 'Queen': 1},
#  ("!'", 'she', 'answered'): {'herself': 1},
#  ("!'", 'she', 'exclaimed'): {'in': 1},
#  ("!'", 'she', 'remarked'): {'.': 1},
#  ("!'", 'she', 'repeated'): {'in': 1},
#  ("!'", 'she', 'said'): {',': 1, 'to': 2},
#  ("!'", 'she', 'thought'): {'.': 1},
#  ("!'", 'shouted', 'Alice'): {'.': 1},
#  ("!'", 'shouted', 'the'): {'Gryphon': 1, 'Queen': 2},
#  ("!'", 'sighed', 'the'): {'Hatter': 1, 'Lory': 1},
#  ("!'", 'the', 'Caterpillar'): {'called': 1},
#  ("!'", 'the', 'Duchess'): {'began': 1, 'said': 1},
#  ("!'", 'the', 'Hatter'): {'said': 1},
#  ("!'", 'the', 'King'): {'added': 1, 'exclaimed': 1},
#  ("!'", 'the', 'March'): {'Hare': 1},
#  ("!'", 'the', 'Mock'): {'Turtle': 1},
#  ("!'", 'the', 'Queen'): {'shouted': 1},
#  ("!'", 'the', 'Rabbit'): {'hastily': 1, 'whispered': 1},
#  ("!'", 'the', 'soldiers'): {'shouted': 1},
#  ("!'", 'then', 'silence'): {',': 1},
#  ("!'", 'then', 'the'): {'Rabbit': 1},
#  ("!'", 'they', 'both'): {'cried': 1},
#  ("!'", 'they', 'cried'): {'out': 1},
#  ("!'", 'thought', 'Alice'): {'.': 5, ';': 1, 'to': 1},
#  ("!'", 'was', 'heard'): {'in': 1},
#  ("!'", 'which', 'produced'): {'another': 1},
#  ("!'", 'yelled', 'the'): {'Gryphon': 1},
#  ("!')", 'The', 'Mouse'): {'looked': 1},
#  ('!--', 'Bill', "'"): {'s': 1},
#  ('!--', 'Here', ','): {'put': 1},
#  ('!--', 'That', 'I'): {'won': 1},
#  ('"', 'Come', 'up'): {'again': 1},
#  ('"', 'Coming', 'in'): {'a': 1},
#  ('"', 'Edwin', 'and'): {'Morcar': 1},
#  ('"', 'French', ','): {'music': 1},
#  ('"', 'HOW', 'DOTH'): {'THE': 1},
#  ('"', 'He', "'"): {'s': 1},
#  ('"', 'How', 'doth'): {'the': 1},
#  ('"', 'I', "'"): {'ll': 2},
#  ('"', 'I', 'breathe'): {'when': 1},
#  ('"', 'I', 'eat'): {'what': 1},
#  ('"', 'I', 'get'): {'what': 1},
#  ('"', 'I', 'like'): {'what': 1},
#  ('"', 'I', 'passed'): {'by': 1},
#  ('"', 'I', 'see'): {'what': 1},
#  ('"', 'I', 'sleep'): {'when': 1},
#  ('"', 'Keep', 'back'): {',': 1},
#  ('"', 'Let', 'us'): {'both': 1},
#  ('"', 'Such', 'a'): {'trial': 1},
#  ('"', 'THEY', 'ALL'): {'RETURNED': 1},
#  ('"', 'There', "'"): {'s': 1},
#  ('"', 'There', 'is'): {'another': 1},
#  ('"', 'There', 'was'): {'some': 1},
#  ('"', 'Too', 'far'): {',': 1},
#  ('"', 'Turtle', 'Soup'): {',"': 1},
#  ('"', 'Twinkle', ','): {'twinkle': 1},
#  ('"', 'Uglification', ',"\''): {'Alice': 1},
#  ('"', 'Up', 'above'): {'the': 1},
#  ('"', 'What', 'a'): {'pity': 1},
#  ('"', 'What', 'for'): {'?"\'': 1},
#  ('"', 'Who', 'am'): {'I': 1},
#  ('"', 'William', 'the'): {'Conqueror': 1},
#  ('"', 'With', 'what'): {'porpoise': 1},
#  ('"', 'YOU', 'ARE'): {'OLD': 1},
#  ('"', 'You', 'can'): {'really': 1},
#  ('"', 'You', 'have'): {'baked': 1},
#  ('"', 'come', 'on'): {'!"': 1},
#  ('"', 'is', 'the'): {'same': 3},
#  ('"', 'it', '"'): {'means': 2},
#  ('"', 'means', ".'"): {"'": 1},
#  ('"', 'means', 'well'): {'enough': 1},
#  ('"', 'much', 'of'): {'a': 1},
#  ('"', 'or', 'not'): {"';": 1},
#  ('"', 'poison', '"'): {'or': 1},
#  ('"', 'purpose', '"?\''): {'said': 1},
#  ('"!\'', "'", 'It'): {'IS': 1},
#  ('"!\'', "'", 'You'): {'might': 2},
#  ('"\'', 'TIS', 'THE'): {'VOICE': 1},
#  ('"--', 'SAID', 'I'): {'COULD': 1},
#  ('"--', 'but', ','): {'oh': 1},
#  ('"--', 'did', 'you'): {'ever': 1},
#  ('"--', 'or', 'if'): {'you': 1},
#  ('"?\'', 'said', 'Alice'): {'.': 1},
#  ("'", 'A', 'barrowful'): {'of': 1, 'will': 1},
#  ("'", 'A', 'cat'): {'may': 1},
#  ("'", 'A', 'cheap'): {'sort': 1},
#  ("'", 'A', 'fine'): {'day': 1},
#  ("'", 'A', 'knot'): {"!'": 1},
#  ("'", 'A', 'likely'): {'story': 1},
#  ("'", 'A', 'mouse'): {'--': 1},
#  ("'", 'A', 'nice'): {'muddle': 1},
#  ("'", 'ARE', 'you'): {'to': 1},
#  ("'", 'After', 'that'): {",'": 1},
#  ("'", 'Ah', '!'): {'that': 1, 'then': 1},
#  ("'", 'Ah', ','): {'my': 1, 'well': 1},
#  ("'", 'Ahem', "!'"): {'said': 1},
#  ("'", 'Alice', "!'"): {'CHAPTER': 1},
#  ("'", 'All', 'right'): {',': 1, ",'": 1},
#  ("'", 'An', 'arm'): {',': 1},
#  ("'", 'And', 'be'): {'quick': 1},
#  ("'", 'And', 'ever'): {'since': 1},
#  ("'", 'And', 'how'): {'did': 1, 'do': 1, 'many': 1},
#  ("'", 'And', 'just'): {'as': 1},
#  ("'", 'And', 'now'): {'which': 1},
#  ("'", 'And', 'so'): {'these': 1},
#  ("'", 'And', 'that'): {"'": 1},
#  ("'", 'And', 'washing'): {"?'": 1},
#  ("'", 'And', 'what'): {'an': 1, 'are': 1},
#  ("'", 'And', 'where'): {'HAVE': 1},
#  ("'", 'And', 'who'): {'are': 1, 'is': 1},
#  ("'", 'And', 'yet'): {'what': 1},
#  ("'", 'And', 'your'): {'hair': 1},
#  ("'", 'Anything', 'you'): {'like': 1},
#  ("'", 'Are', 'their'): {'heads': 1},
#  ("'", 'Are', 'they'): {'in': 1},
#  ("'", 'Are', 'you'): {'--': 1, 'content': 1},
#  ("'", 'As', 'if'): {'I': 1, 'it': 1},
#  ("'", 'As', 'wet'): {'as': 1},
#  ("'", 'At', 'any'): {'rate': 1},
#  ("'", 'Back', 'to'): {'land': 1},
#  ("'", 'Beautiful', 'Soup'): {'!': 1, ',': 1},
#  ("'", 'Begin', 'at'): {'the': 1},
#  ("'", 'Behead', 'that'): {'Dormouse': 1},
#  ("'", 'Boots', 'and'): {'shoes': 1},
#  ("'", 'Bring', 'me'): {'the': 1},
#  ("'", 'But', ','): {'it': 1},
#  ("'", 'But', 'I'): {"'": 2, 'don': 2},
#  ("'", 'But', 'about'): {'his': 1},
#  ("'", 'But', 'everything'): {"'": 1},
#  ("'", 'But', 'it'): {"'": 1},
#  ("'", 'But', 'perhaps'): {'he': 1, 'it': 1},
#  ("'", 'But', 'she'): {'must': 1},
#  ("'", 'But', 'then'): {",'": 1},
#  ("'", 'But', 'they'): {'were': 1},
#  ("'", 'But', 'what'): {'am': 1, 'did': 1, 'happens': 1},
#  ("'", 'But', 'who'): {'has': 1, 'is': 1},
#  ("'", 'But', 'why'): {'did': 1},
#  ("'", 'But', 'you'): {"'": 1},
#  ("'", 'By', '-'): {'the': 1},
#  ("'", 'Call', 'it'): {'what': 1},
#  ("'", 'Call', 'the'): {'first': 1, 'next': 2},
#  ("'", 'Can', "'"): {'t': 1},
#  ("'", 'Can', 'you'): {'play': 1},
#  ("'", 'Certainly', 'not'): {"!'": 1},
#  ("'", 'Change', 'lobsters'): {'again': 1},
#  ("'", 'Cheshire', 'Puss'): {",'": 1},
#  ("'", 'Chorus', 'again'): {"!'": 1},
#  ("'", 'Collar', 'that'): {'Dormouse': 1},
#  ("'", 'Come', ','): {'THAT': 1,
#                       'it': 1,
#                       'let': 2,
#                       'my': 1,
#                       'that': 1,
#                       'there': 2,
#                       'we': 1},
#  ("'", 'Come', 'away'): {',': 1},
#  ("'", 'Come', 'back'): {"!'": 1},
#  ("'", 'Come', 'on'): {"!'": 2, ',': 2},
#  ("'", 'Consider', ','): {'my': 1},
#  ("'", 'Consider', 'your'): {'verdict': 2},
#  ("'", 'Curiouser', 'and'): {'curiouser': 1},
#  ("'", 'D', 'better'): {'not': 1},
#  ("'", 'DRINK', 'ME'): {"'": 1, ",'": 1},
#  ("'", 'Dear', ','): {'dear': 1},
#  ("'", 'Did', 'you'): {'say': 2, 'speak': 1},
#  ("'", 'Digging', 'for'): {'apples': 1},
#  ("'", 'Dinah', "'"): {'ll': 1, 's': 1},
#  ("'", 'Do', 'I'): {'look': 1},
#  ("'", 'Do', 'as'): {'I': 1},
#  ("'", 'Do', 'bats'): {'eat': 1},
#  ("'", 'Do', 'cats'): {'eat': 1},
#  ("'", 'Do', 'you'): {'know': 1, 'mean': 1, 'play': 1, 'take': 1},
#  ("'", 'Does', 'YOUR'): {'watch': 1},
#  ("'", 'Does', 'the'): {'boots': 1},
#  ("'", 'Don', "'"): {'t': 4},
#  ("'", 'Drink', 'me'): {",'": 1},
#  ("'", 'Drive', 'on'): {',': 1},
#  ("'", 'EAT', 'ME'): {"'": 1},
#  ("'", 'EVERYBODY', 'has'): {'won': 1},
#  ("'", 'Each', 'with'): {'a': 1},
#  ("'", 'Everybody', 'says'): {'"': 1},
#  ("'", 'Everything', "'"): {'s': 1},
#  ("'", 'Exactly', 'so'): {",'": 2},
#  ("'", 'Explain', 'all'): {'that': 1},
#  ("'", 'Explain', 'yourself'): {"!'": 1},
#  ("'", 'Fetch', 'me'): {'my': 1},
#  ("'", 'Fifteenth', ",'"): {'said': 1},
#  ("'", 'First', 'witness'): {"!'": 1},
#  ("'", 'For', 'the'): {'Duchess': 1},
#  ("'", 'Found', 'IT'): {",'": 1},
#  ("'", 'Found', 'WHAT'): {"?'": 1},
#  ("'", 'Fourteenth', 'of'): {'March': 1},
#  ("'", 'From', 'the'): {'Queen': 1},
#  ("'", 'Fury', 'said'): {'to': 1},
#  ("'", 'Get', 'to'): {'your': 1},
#  ("'", 'Get', 'up'): {"!'": 1},
#  ("'", 'Give', 'your'): {'evidence': 3},
#  ("'", 'Go', 'on'): {'with': 2},
#  ("'", 'HE', 'might'): {'bite': 1},
#  ("'", 'Hadn', "'"): {'t': 1},
#  ("'", 'Hand', 'it'): {'over': 1},
#  ("'", 'Have', 'some'): {'wine': 1},
#  ("'", 'Have', 'you'): {'guessed': 1, 'seen': 1},
#  ("'", 'He', 'denies'): {'it': 1},
#  ("'", 'He', 'must'): {'have': 1},
#  ("'", 'He', 'took'): {'me': 1},
#  ("'", 'He', 'won'): {"'": 1},
#  ("'", 'Herald', ','): {'read': 1},
#  ("'", 'Here', '!'): {'Come': 1, 'you': 1},
#  ("'", 'Here', "!'"): {'cried': 1},
#  ("'", 'Hjckrrh', "!'"): {'from': 1},
#  ("'", 'Hm', '!'): {'No': 1},
#  ("'", 'Hold', 'your'): {'tongue': 3},
#  ("'", 'How', 'CAN'): {'I': 1},
#  ("'", 'How', 'COULD'): {'he': 1},
#  ("'", 'How', 'am'): {'I': 1},
#  ("'", 'How', 'are'): {'you': 1},
#  ("'", 'How', 'can'): {'you': 1},
#  ("'", 'How', 'cheerfully'): {'he': 1},
#  ("'", 'How', 'do'): {'you': 2},
#  ("'", 'How', 'doth'): {'the': 1},
#  ("'", 'How', 'dreadfully'): {'savage': 1},
#  ("'", 'How', 'fond'): {'she': 1},
#  ("'", 'How', 'queer'): {'it': 1},
#  ("'", 'How', 'should'): {'I': 1},
#  ("'", 'How', 'surprised'): {'he': 1},
#  ("'", 'How', 'the'): {'creatures': 1},
#  ("'", 'Hush', '!'): {'Hush': 1},
#  ("'", 'I', "'"): {'M': 1, 'VE': 1, 'd': 4, 'll': 5, 'm': 19, 've': 13},
#  ("'", 'I', '--'): {'I': 2},
#  ("'", 'I', 'DON'): {"'": 1},
#  ("'", 'I', 'HAVE'): {'tasted': 1},
#  ("'", 'I', 'advise'): {'you': 1},
#  ("'", 'I', 'am'): {'older': 1},
#  ("'", 'I', 'beg'): {'pardon': 1, 'your': 2},
#  ("'", 'I', 'believe'): {'so': 1},
#  ("'", 'I', 'call'): {'it': 1},
#  ("'", 'I', 'can'): {"'": 4, 'hardly': 1, 'see': 1, 'tell': 1},
#  ("'", 'I', 'could'): {'tell': 1},
#  ("'", 'I', 'couldn'): {"'": 2},
#  ("'", 'I', 'cut'): {'some': 1},
#  ("'", 'I', 'dare'): {'say': 2},
#  ("'", 'I', 'daresay'): {'it': 1},
#  ("'", 'I', 'deny'): {'it': 1},
#  ("'", 'I', 'didn'): {"'": 5},
#  ("'", 'I', 'do'): {",'": 1, 'wish': 1},
#  ("'", 'I', 'don'): {"'": 15},
#  ("'", 'I', 'feared'): {'it': 1},
#  ("'", 'I', 'had'): {'NOT': 1},
#  ("'", 'I', 'have'): {'answered': 1},
#  ("'", 'I', 'haven'): {"'": 3},
#  ("'", 'I', 'heard'): {'every': 1, 'the': 1},
#  ("'", 'I', 'hope'): {'they': 1},
#  ("'", 'I', 'keep'): {'them': 1},
#  ("'", 'I', 'kept'): {'all': 1},
#  ("'", 'I', 'know'): {'SOMETHING': 1, 'what': 1},
#  ("'", 'I', 'make'): {'you': 1},
#  ("'", 'I', 'mean'): {',': 1, 'what': 1},
#  ("'", 'I', 'might'): {'as': 1},
#  ("'", 'I', 'move'): {'that': 1},
#  ("'", 'I', 'must'): {'be': 4, 'go': 1},
#  ("'", 'I', 'never'): {'could': 1,
#                        'heard': 1,
#                        'said': 1,
#                        'saw': 1,
#                        'thought': 1,
#                        'was': 1,
#                        'went': 1},
#  ("'", 'I', 'once'): {'tasted': 1},
#  ("'", 'I', 'only'): {'took': 1},
#  ("'", 'I', 'passed'): {'by': 1},
#  ("'", 'I', 'quite'): {'agree': 1, 'forgot': 1},
#  ("'", 'I', 'really'): {'must': 1},
#  ("'", 'I', 'said'): {'pig': 1},
#  ("'", 'I', 'see'): {"!'": 1},
#  ("'", 'I', 'seem'): {'to': 1},
#  ("'", 'I', 'shall'): {'be': 1, 'do': 1, 'sit': 2},
#  ("'", 'I', 'should'): {'have': 1, 'like': 3, 'think': 1},
#  ("'", 'I', 'speak'): {'severely': 1},
#  ("'", 'I', 'suppose'): {'so': 1, 'they': 1},
#  ("'", 'I', 'think'): {',': 1, 'I': 1, 'you': 1},
#  ("'", 'I', 'thought'): {'it': 1, 'you': 1},
#  ("'", 'I', 'told'): {'you': 1},
#  ("'", 'I', 'took'): {'to': 1},
#  ("'", 'I', 'want'): {'a': 1},
#  ("'", 'I', 'was'): {'a': 1},
#  ("'", 'I', 'wasn'): {"'": 1},
#  ("'", 'I', 'went'): {'to': 1},
#  ("'", 'I', 'wish'): {'I': 3, 'the': 1, 'you': 1},
#  ("'", 'I', 'won'): {"'": 4},
#  ("'", 'I', 'wonder'): {'how': 1, 'if': 1, 'what': 2},
#  ("'", 'IF', 'I'): {'don': 1},
#  ("'", 'IT', 'DOES'): {'THE': 1},
#  ("'", 'Idiot', "!'"): {'said': 1},
#  ("'", 'If', 'I'): {"'": 1, 'eat': 1},
#  ("'", 'If', 'any'): {'one': 1},
#  ("'", 'If', 'everybody'): {'minded': 1},
#  ("'", 'If', 'it'): {'had': 1},
#  ("'", 'If', 'that'): {"'": 1},
#  ("'", 'If', 'there'): {"'": 1},
#  ("'", 'If', 'you'): {"'": 1,
#                       'can': 1,
#                       'didn': 1,
#                       'do': 1,
#                       'knew': 1,
#                       'please': 1},
#  ("'", 'In', 'THAT'): {'direction': 1},
#  ("'", 'In', 'my'): {'youth': 3},
#  ("'", 'In', 'that'): {'case': 1},
#  ("'", 'Is', 'that'): {'all': 1, 'the': 2},
#  ("'", 'It', "'"): {'s': 16},
#  ("'", 'It', 'IS'): {'a': 1, 'the': 1},
#  ("'", 'It', 'WAS'): {'a': 1},
#  ("'", 'It', 'all'): {'came': 1},
#  ("'", 'It', 'began'): {'with': 1},
#  ("'", 'It', 'belongs'): {'to': 1},
#  ("'", 'It', 'goes'): {'on': 1},
#  ("'", 'It', 'is'): {'a': 1, 'wrong': 1},
#  ("'", 'It', 'isn'): {"'": 4},
#  ("'", 'It', 'matters'): {'a': 1},
#  ("'", 'It', 'must'): {'be': 1, 'have': 1},
#  ("'", 'It', 'proves'): {'nothing': 1},
#  ("'", 'It', 'tells'): {'the': 1},
#  ("'", 'It', 'turned'): {'into': 1},
#  ("'", 'It', 'was'): {'a': 1, 'much': 1, 'the': 2},
#  ("'", 'It', 'wasn'): {"'": 1},
#  ("'", 'Just', 'about'): {'as': 1},
#  ("'", 'Just', 'think'): {'of': 1},
#  ("'", 'Keep', 'your'): {'temper': 1},
#  ("'", 'LL', 'soon'): {'make': 1},
#  ("'", 'Leave', 'off'): {'that': 1},
#  ("'", 'Let', "'"): {'s': 1},
#  ("'", 'Let', 'me'): {'alone': 1},
#  ("'", 'Let', 'the'): {'jury': 1},
#  ("'", 'Let', 'us'): {'get': 1},
#  ("'", 'Look', 'out'): {'now': 1},
#  ("'", 'M', 'a'): {'Duchess': 1},
#  ("'", 'M', 'not'): {'a': 1},
#  ("'", 'Mary', 'Ann'): {'!': 1},
#  ("'", 'May', 'it'): {'please': 1},
#  ("'", 'Mine', 'is'): {'a': 1},
#  ("'", 'Mouse', 'dear'): {'!': 1},
#  ("'", 'My', 'dear'): {'!': 1},
#  ("'", 'My', 'name'): {'is': 1},
#  ("'", 'Nearly', 'two'): {'miles': 1},
#  ("'", 'Never', "!'"): {'said': 1},
#  ("'", 'Never', 'mind'): {"!'": 1},
#  ("'", 'No', ','): {'I': 3,
#                     'indeed': 1,
#                     'never': 1,
#                     'no': 2,
#                     'please': 1,
#                     'they': 1},
#  ("'", 'No', ",'"): {'said': 2},
#  ("'", 'No', 'room'): {'!': 1},
#  ("'", 'Nobody', 'asked'): {'YOUR': 1},
#  ("'", 'Nobody', 'seems'): {'to': 1},
#  ("'", 'Nonsense', "!'"): {'said': 1},
#  ("'", 'Nor', 'I'): {",'": 1},
#  ("'", 'Not', 'I'): {"!'": 2},
#  ("'", 'Not', 'QUITE'): {'right': 1},
#  ("'", 'Not', 'a'): {'bit': 1},
#  ("'", 'Not', 'at'): {'all': 1, 'first': 1},
#  ("'", 'Not', 'like'): {'cats': 1},
#  ("'", 'Not', 'the'): {'same': 1},
#  ("'", 'Not', 'yet'): {',': 1},
#  ("'", 'Nothing', ",'"): {'said': 1},
#  ("'", 'Nothing', 'WHATEVER'): {"?'": 1},
#  ("'", 'Nothing', 'can'): {'be': 1},
#  ("'", 'Nothing', 'whatever'): {",'": 1},
#  ("'", 'Now', ','): {'Dinah': 1, 'I': 2, 'what': 1},
#  ("'", 'Now', 'I'): {'can': 1},
#  ("'", 'Now', 'at'): {'OURS': 1},
#  ("'", 'Now', 'tell'): {'me': 1},
#  ("'", 'Now', 'we'): {'shall': 1},
#  ("'", 'O', 'Mouse'): {',': 1},
#  ("'", 'ORANGE', 'MARMALADE'): {"',": 1},
#  ("'", 'Of', 'course'): {',': 1,
#                          ",'": 2,
#                          'it': 2,
#                          'not': 2,
#                          'they': 1,
#                          'twinkling': 1,
#                          'you': 1},
#  ("'", 'Of', 'the'): {'mushroom': 1},
#  ("'", 'Off', 'with'): {'her': 4, 'his': 3, 'their': 1},
#  ("'", 'Oh', '!'): {'So': 1, 'the': 1},
#  ("'", 'Oh', ','): {'I': 5,
#                     'PLEASE': 1,
#                     'YOU': 1,
#                     'a': 1,
#                     'as': 1,
#                     'do': 1,
#                     'don': 2,
#                     'hush': 1,
#                     'my': 1,
#                     'there': 2,
#                     'you': 3},
#  ("'", 'Oh', 'dear'): {'!': 1},
#  ("'", 'Oh', 'my'): {'ears': 1},
#  ("'", 'Once', ",'"): {'said': 1},
#  ("'", 'Once', 'upon'): {'a': 1},
#  ("'", 'One', ','): {'indeed': 1, 'two': 1},
#  ("'", 'One', 'side'): {'of': 1, 'will': 1},
#  ("'", 'Only', 'a'): {'thimble': 1},
#  ("'", 'Only', 'mustard'): {'isn': 1},
#  ("'", 'Or', 'would'): {'you': 1},
#  ("'", 'Ou', 'est'): {'ma': 1},
#  ("'", 'Pepper', ','): {'mostly': 1},
#  ("'", 'Perhaps', 'it'): {'doesn': 1, 'hasn': 1},
#  ("'", 'Perhaps', 'not'): {",'": 1},
#  ("'", 'Please', ','): {'then': 1},
#  ("'", 'Please', 'come'): {'back': 1},
#  ("'", 'Please', 'would'): {'you': 1},
#  ("'", 'Please', 'your'): {'Majesty': 1},
#  ("'", 'Poor', 'little'): {'thing': 1},
#  ("'", 'Pray', 'don'): {"'": 1},
#  ("'", 'Prizes', '!'): {'Prizes': 1},
#  ("'", 'Read', 'them'): {",'": 1},
#  ("'", 'Really', ','): {'my': 1, 'now': 1},
#  ("'", 'Reeling', 'and'): {'Writhing': 1},
#  ("'", 'Repeat', ','): {'"': 1},
#  ("'", 'Right', ','): {'as': 1},
#  ("'", 'Rule', 'Forty'): {'-': 1},
#  ("'", 'S', 'LOVE'): {').': 1},
#  ("'", 'S', 'RIGHT'): {'FOOT': 1},
#  ("'", 'S', 'a'): {'good': 1},
#  ("'", 'S', 'all'): {'wrong': 1},
#  ("'", 'S', 'she'): {',': 1},
#  ("'", 'S', 'the'): {'great': 1},
#  ("'", 'SHE', 'doesn'): {"'": 1},
#  ("'", 'Same', 'as'): {'if': 1},
#  ("'", 'Seals', ','): {'turtles': 1},
#  ("'", 'Sentence', 'first'): {'--': 1},
#  ("'", 'Serpent', "!'"): {'screamed': 1},
#  ("'", 'Serpent', ','): {'I': 1},
#  ("'", 'Seven', 'jogged'): {'my': 1},
#  ("'", 'Sh', '!'): {'sh': 1},
#  ("'", 'Shall', 'we'): {'try': 1},
#  ("'", 'Shan', "'"): {'t': 1},
#  ("'", 'She', "'"): {'d': 1, 's': 2},
#  ("'", 'She', 'boxed'): {'the': 1},
#  ("'", 'She', 'can'): {"'": 1},
#  ("'", 'Shy', ','): {'they': 1},
#  ("'", 'Silence', "!'"): {'and': 1},
#  ("'", 'Silence', 'in'): {'the': 1},
#  ("'", 'Sit', 'down'): {',': 1},
#  ("'", 'Sixteenth', ",'"): {'added': 1},
#  ("'", 'So', 'he'): {'did': 1},
#  ("'", 'So', 'they'): {'were': 1},
#  ("'", 'So', 'you'): {'did': 1, 'think': 1},
#  ("'", 'Soles', 'and'): {'eels': 1},
#  ("'", 'Somebody', 'said'): {",'": 1},
#  ("'", 'Soo', '--'): {'oop': 1},
#  ("'", 'Speak', 'English'): {"!'": 1},
#  ("'", 'Speak', 'roughly'): {'to': 1},
#  ("'", 'Stand', 'up'): {'and': 1},
#  ("'", 'Stolen', "!'"): {'the': 1},
#  ("'", 'Stuff', 'and'): {'nonsense': 1},
#  ("'", 'Stupid', 'things'): {"!'": 1},
#  ("'", 'Suppose', 'it'): {'should': 1},
#  ("'", 'Suppose', 'we'): {'change': 1},
#  ("'", 'Sure', ','): {'I': 1, 'it': 2},
#  ("'", 'Sure', 'then'): {'I': 1},
#  ("'", 'Swim', 'after'): {'them': 1},
#  ("'", 'T', 'know'): {",'": 1},
#  ("'", 'THAT', 'generally'): {'takes': 1},
#  ("'", 'THAT', 'you'): {'won': 1},
#  ("'", 'Take', 'off'): {'your': 1},
#  ("'", 'Take', 'some'): {'more': 1},
#  ("'", 'Talking', 'of'): {'axes': 1},
#  ("'", 'Tell', 'us'): {'a': 1},
#  ("'", 'Ten', 'hours'): {'the': 1},
#  ("'", 'Thank', 'you'): {',': 2, ",'": 1},
#  ("'", 'That', "'"): {'s': 14},
#  ("'", 'That', 'I'): {'can': 1},
#  ("'", 'That', 'PROVES'): {'his': 1},
#  ("'", 'That', 'WAS'): {'a': 1},
#  ("'", 'That', 'depends'): {'a': 1},
#  ("'", 'That', 'is'): {'not': 1},
#  ("'", 'That', 'would'): {'be': 1},
#  ("'", 'The', 'Dormouse'): {'is': 1},
#  ("'", 'The', 'Duchess'): {'!': 1},
#  ("'", 'The', 'Queen'): {'!': 1, 'of': 1, 'will': 1},
#  ("'", 'The', 'first'): {'thing': 1},
#  ("'", 'The', 'fourth'): {".'": 1},
#  ("'", 'The', 'game'): {"'": 1},
#  ("'", 'The', 'idea'): {'of': 1},
#  ("'", 'The', 'lobsters'): {"!'": 1},
#  ("'", 'The', 'race'): {'is': 1},
#  ("'", 'The', 'reason'): {'is': 1},
#  ("'", 'The', 'trial'): {"'": 1, 'cannot': 1},
#  ("'", 'The', 'twinkling'): {'of': 1},
#  ("'", 'Their', 'heads'): {'are': 1},
#  ("'", 'Then', ','): {'you': 1},
#  ("'", 'Then', 'I'): {"'": 1},
#  ("'", 'Then', 'it'): {'doesn': 1, 'ought': 1, 'wasn': 1},
#  ("'", 'Then', 'the'): {'Dormouse': 1, 'eleventh': 1, 'words': 1},
#  ("'", 'Then', 'you'): {'keep': 1, 'may': 1, 'should': 1, 'shouldn': 1},
#  ("'", 'There', "'"): {'s': 6},
#  ("'", 'There', 'goes'): {'Bill': 1},
#  ("'", 'There', 'is'): {'such': 1},
#  ("'", 'There', 'isn'): {"'": 1},
#  ("'", 'There', 'might'): {'be': 1},
#  ("'", 'They', "'"): {'re': 2},
#  ("'", 'They', 'all'): {'can': 1},
#  ("'", 'They', 'can'): {"'": 1},
#  ("'", 'They', 'couldn'): {"'": 1},
#  ("'", 'They', 'have'): {'their': 1},
#  ("'", 'They', 'lived'): {'on': 1},
#  ("'", 'They', 'must'): {'go': 1},
#  ("'", 'They', 'told'): {'me': 1},
#  ("'", 'They', 'were'): {'learning': 1, 'obliged': 1},
#  ("'", 'Thinking', 'again'): {"?'": 1},
#  ("'", 'This', 'here'): {'young': 1},
#  ("'", 'This', 'is'): {'Bill': 1},
#  ("'", 'To', 'begin'): {'with': 1},
#  ("'", 'Treacle', ",'"): {'said': 2},
#  ("'", 'Turn', 'a'): {'somersault': 1},
#  ("'", 'Turn', 'them'): {'over': 1},
#  ("'", 'Tut', ','): {'tut': 1},
#  ("'", 'Twenty', '-'): {'four': 1},
#  ("'", 'Twinkle', ','): {'twinkle': 1},
#  ("'", 'Two', 'days'): {'wrong': 1},
#  ("'", 'Two', 'lines'): {"!'": 1},
#  ("'", 'UNimportant', ','): {'of': 1, 'your': 1},
#  ("'", 'Ugh', "!'"): {'said': 1},
#  ("'", 'Up', ','): {'lazy': 1},
#  ("'", 'VE', 'been'): {'to': 1},
#  ("'", 'VERY', 'ill'): {".'": 1},
#  ("'", 'Very', ",'"): {'said': 1},
#  ("'", 'Very', 'much'): {'indeed': 1},
#  ("'", 'Very', 'true'): {",'": 1},
#  ("'", 'Very', 'uncomfortable'): {'for': 1},
#  ("'", 'W', '.'): {'RABBIT': 1},
#  ("'", 'Wake', 'up'): {',': 2},
#  ("'", 'We', 'beg'): {'your': 1},
#  ("'", 'We', 'called'): {'him': 1},
#  ("'", 'We', 'can'): {'do': 1},
#  ("'", 'We', 'had'): {'the': 1},
#  ("'", 'We', 'indeed'): {"!'": 1},
#  ("'", 'We', 'must'): {'burn': 1},
#  ("'", 'We', 'quarrelled'): {'last': 1},
#  ("'", 'We', 'won'): {"'": 1},
#  ("'", 'Well', '!'): {'I': 1, 'WHAT': 1},
#  ("'", 'Well', "!'"): {'thought': 1},
#  ("'", 'Well', ','): {'I': 8,
#                       'at': 1,
#                       'be': 1,
#                       'if': 1,
#                       'it': 2,
#                       'of': 1,
#                       'perhaps': 3,
#                       'then': 2,
#                       'there': 1},
#  ("'", 'What', '!'): {'Never': 1},
#  ("'", 'What', "'"): {'s': 2},
#  ("'", 'What', 'CAN'): {'all': 1},
#  ("'", 'What', 'HAVE'): {'you': 1},
#  ("'", 'What', 'I'): {'was': 1},
#  ("'", 'What', 'IS'): {'a': 1, 'the': 2},
#  ("'", 'What', 'a'): {'curious': 2, 'funny': 1, 'number': 1, 'pity': 1},
#  ("'", 'What', 'are'): {'tarts': 1, 'they': 1, 'you': 1},
#  ("'", 'What', 'day'): {'of': 1},
#  ("'", 'What', 'did'): {'they': 2},
#  ("'", 'What', 'do'): {'you': 2},
#  ("'", 'What', 'else'): {'had': 1, 'have': 1},
#  ("'", 'What', 'for'): {"?'": 2},
#  ("'", 'What', 'fun'): {"!'": 1},
#  ("'", 'What', 'is'): {'his': 1, 'it': 1},
#  ("'", 'What', 'size'): {'do': 1},
#  ("'", 'What', 'sort'): {'of': 2},
#  ("'", 'What', 'trial'): {'is': 1},
#  ("'", 'What', 'was'): {'THAT': 1, 'that': 1},
#  ("'", 'When', 'I'): {"'": 1},
#  ("'", 'When', 'did'): {'you': 1},
#  ("'", 'When', 'we'): {'were': 1},
#  ("'", 'Where', "'"): {'s': 1},
#  ("'", 'Where', 'shall'): {'I': 1},
#  ("'", 'Which', 'is'): {'just': 1},
#  ("'", 'Which', 'way'): {'?': 1},
#  ("'", 'Which', 'would'): {'NOT': 1},
#  ("'", 'Who', "'"): {'s': 1},
#  ("'", 'Who', 'ARE'): {'you': 1},
#  ("'", 'Who', 'are'): {'YOU': 2},
#  ("'", 'Who', 'cares'): {'for': 1},
#  ("'", 'Who', 'is'): {'it': 1, 'this': 1},
#  ("'", 'Whoever', 'lives'): {'there': 1},
#  ("'", 'Why', ','): {'Mary': 1,
#                      'SHE': 2,
#                      'there': 1,
#                      'they': 1,
#                      'what': 2,
#                      'you': 1},
#  ("'", 'Why', ",'"): {'said': 2},
#  ("'", 'Why', "?'"): {"'": 1, 'said': 1},
#  ("'", 'Why', 'did'): {'they': 1, 'you': 1},
#  ("'", 'Why', 'is'): {'a': 1},
#  ("'", 'Why', 'not'): {"?'": 1},
#  ("'", 'Why', 'should'): {'it': 1},
#  ("'", 'Why', 'the'): {'fact': 1},
#  ("'", 'Why', 'with'): {'an': 1},
#  ("'", 'With', 'extras'): {"?'": 1},
#  ("'", 'Would', 'YOU'): {'like': 1},
#  ("'", 'Would', 'it'): {'be': 1},
#  ("'", 'Would', 'you'): {'like': 1, 'tell': 2},
#  ("'", 'Wouldn', "'"): {'t': 1},
#  ("'", 'Wow', '!'): {'wow': 2},
#  ("'", 'Write', 'that'): {'down': 1},
#  ("'", 'YOU', "'"): {'D': 1},
#  ("'", 'YOU', 'ARE'): {'OLD': 1},
#  ("'", 'Yes', "!'"): {'shouted': 1},
#  ("'", 'Yes', ','): {'I': 1,
#                      'but': 2,
#                      'it': 1,
#                      'please': 2,
#                      'that': 1,
#                      'we': 1},
#  ("'", 'Yes', ",'"): {'said': 3},
#  ("'", 'You', "!'"): {'said': 1},
#  ("'", 'You', "'"): {'d': 1, 'll': 2, 're': 6, 've': 1},
#  ("'", 'You', 'MUST'): {'remember': 1},
#  ("'", 'You', 'are'): {",'": 1, 'all': 1, 'not': 1, 'old': 4},
#  ("'", 'You', 'can'): {"'": 1, 'draw': 1},
#  ("'", 'You', 'couldn'): {"'": 1},
#  ("'", 'You', 'did'): {"!'": 1, ",'": 1},
#  ("'", 'You', 'don'): {"'": 1},
#  ("'", 'You', 'insult'): {'me': 1},
#  ("'", 'You', 'know'): {'what': 1},
#  ("'", 'You', 'make'): {'me': 1},
#  ("'", 'You', 'may'): {'go': 1, 'not': 1},
#  ("'", 'You', 'mean'): {'you': 1},
#  ("'", 'You', 'might'): {'just': 3},
#  ("'", 'You', 'must'): {'be': 1},
#  ("'", 'You', 'ought'): {'to': 3},
#  ("'", 'You', 'promised'): {'to': 1},
#  ("'", 'You', 'shan'): {"'": 1},
#  ("'", 'You', 'should'): {'learn': 1},
#  ("'", 'Your', 'Majesty'): {'must': 1},
#  ("'", 'Your', 'hair'): {'wants': 1},
#  ("'", 'a', 'dog'): {"'": 1},
#  ("'", 'a', 'great'): {'girl': 1},
#  ("'", 'advance', 'twice'): {',': 1},
#  ("'", 'after', 'such'): {'a': 1},
#  ("'", 'all', 'I'): {'know': 1},
#  ("'", 'allow', 'me'): {'to': 1},
#  ("'", 'am', ','): {'is': 1},
#  ("'", 'and', 'I'): {"'": 1, 'do': 1, 'wish': 1},
#  ("'", 'and', 'besides'): {',': 1},
#  ("'", 'and', 'don'): {"'": 2},
#  ("'", 'and', 'even'): {'if': 1},
#  ("'", 'and', 'go'): {'on': 1},
#  ("'", 'and', 'hand'): {'round': 1},
#  ("'", 'and', 'he'): {'shall': 1},
#  ("'", 'and', 'how'): {'funny': 1},
#  ("'", 'and', 'if'): {'it': 1},
#  ("'", 'and', 'in'): {'that': 1},
#  ("'", 'and', 'just'): {'as': 1},
#  ("'", 'and', 'most'): {'of': 1, 'things': 1},
#  ("'", 'and', 'now'): {'for': 1},
#  ("'", 'and', 'see'): {'whether': 1},
#  ("'", 'and', 'she'): {'sits': 1},
#  ("'", 'and', 'take'): {'this': 1},
#  ("'", 'and', 'that'): {"'": 3, 'for': 1},
#  ("'", 'and', 'the'): {'moral': 3},
#  ("'", 'and', 'their'): {'names': 1},
#  ("'", 'and', 'then'): {",'": 1, 'the': 1},
#  ("'", 'and', 'they'): {'all': 1, 'drew': 1},
#  ("'", 'and', 'things'): {'are': 1},
#  ("'", 'and', 'those'): {'twelve': 1},
#  ("'", 'and', 'vinegar'): {'that': 1},
#  ("'", 'and', 'what'): {'is': 1},
#  ("'", 'and', 'why'): {'it': 1},
#  ("'", 'and', 'your'): {'jaws': 1},
#  ("'", 'any', 'shrimp'): {'could': 1},
#  ("'", 'are', 'done'): {'with': 1},
#  ("'", 'are', 'you'): {'all': 1},
#  ("'", 'arrum', ".')"): {"'": 1},
#  ("'", 'as', 'I'): {'mentioned': 1},
#  ("'", 'as', 'all'): {'the': 1},
#  ("'", 'as', 'pigs'): {'have': 1},
#  ("'", 'as', 'the'): {'things': 1},
#  ("'", 'at', 'least'): {'--': 1, 'there': 1},
#  ("'", 'beautifully', 'printed'): {'on': 1},
#  ("'", 'because', 'I'): {"'": 1},
#  ("'", 'because', 'of'): {'his': 1},
#  ("'", 'because', 'they'): {'lessen': 1},
#  ("'", 'besides', ','): {'that': 1},
#  ("'", 'but', 'I'): {"'": 1, 'haven': 1, 'know': 1, 'must': 1},
#  ("'", 'but', 'a'): {'grin': 1},
#  ("'", 'but', 'if'): {'they': 1, 'you': 1},
#  ("'", 'but', 'it'): {"'": 1, 'doesn': 2, 'seems': 1, 'sounds': 1},
#  ("'", 'but', 'little'): {'girls': 1},
#  ("'", 'but', 'that'): {"'": 1},
#  ("'", 'but', 'then'): {'--': 1},
#  ("'", 'but', 'those'): {'serpents': 1},
#  ("'", 'but', 'when'): {'you': 1},
#  ("'", 'but', 'why'): {'do': 1},
#  ("'", 'but', 'you'): {'could': 1},
#  ("'", 'chop', 'off'): {'her': 1},
#  ("'", 'clock', 'in'): {'the': 1},
#  ("'", 'clock', 'it'): {'is': 1},
#  ("'", 'clock', 'now'): {".'": 1},
#  ("'", 'creatures', ",'"): {'you': 1},
#  ("'", 'crumbs', 'would'): {'all': 1},
#  ("'", 'd', 'been'): {'the': 1},
#  ("'", 'd', 'better'): {'ask': 1, 'finish': 1, 'leave': 1, 'not': 1, 'take': 1},
#  ("'", 'd', 'do'): {'almost': 1},
#  ("'", 'd', 'get'): {'the': 1},
#  ("'", 'd', 'gone'): {'to': 1},
#  ("'", 'd', 'hardly'): {'finished': 1},
#  ("'", 'd', 'have'): {'been': 1, 'everybody': 1, 'said': 1, 'signed': 1},
#  ("'", 'd', 'let'): {'Dinah': 1},
#  ("'", 'd', 'like'): {'it': 1},
#  ("'", 'd', 'nearly'): {'forgotten': 2},
#  ("'", 'd', 'only'): {'been': 1, 'have': 1},
#  ("'", 'd', 'rather'): {'finish': 1, 'not': 2},
#  ("'", 'd', 'soon'): {'fetch': 1},
#  ("'", 'd', 'take'): {'a': 1, 'the': 1},
#  ("'", 'd', 'taken'): {'the': 1},
#  ("'", 'don', "'"): {'t': 2},
#  ("'", 'either', 'you'): {'or': 1},
#  ("'", 'em', 'do'): {".'": 1},
#  ("'", 'em', 'together'): {'first': 1},
#  ("'", 'em', 'up'): {'at': 1},
#  ("'", 'engraved', 'upon'): {'it': 1},
#  ("'", 'explanations', 'take'): {'such': 1},
#  ("'", 'fetch', 'her'): {'here': 1},
#  ("'", 'flamingoes', 'and'): {'mustard': 1},
#  ("'", 'for', 'I'): {'can': 1, 'never': 1},
#  ("'", 'for', 'bringing'): {'these': 1},
#  ("'", 'for', 'fear'): {'they': 1},
#  ("'", 'for', 'her'): {'hair': 1},
#  ("'", 'for', 'it'): {'might': 1},
#  ("'", 'he', "'"): {'s': 1},
#  ("'", 'he', 'taught'): {'Laughing': 1},
#  ("'", 'he', 'won'): {"'": 1},
#  ("'", 'his', 'eyes'): {'are': 1},
#  ("'", 'how', 'am'): {'I': 1},
#  ("'", 'however', ','): {'it': 1},
#  ("'", 'if', 'I'): {'had': 1},
#  ("'", 'if', 'one'): {'only': 1},
#  ("'", 'if', 'people'): {'had': 1},
#  ("'", 'if', 'we'): {'had': 1},
#  ("'", 'if', 'you'): {'don': 2, 'only': 1},
#  ("'", 'important', ",'"): {'and': 1},
#  ("'", 'important', '--'): {'unimportant': 1},
#  ("'", 'in', 'fact'): {',': 1},
#  ("'", 'in', 'my'): {'going': 1},
#  ("'", 'in', 'this'): {'way': 1},
#  ("'", 'is', 'to'): {'grow': 1},
#  ("'", 'it', "'"): {'ll': 1, 's': 8},
#  ("'", 'it', 'begins'): {'"': 1},
#  ("'", 'it', 'doesn'): {"'": 1},
#  ("'", 'it', 'means'): {'--': 1},
#  ("'", 'it', 'would'): {'be': 1, 'have': 1},
#  ("'", 'jury', '-'): {'men': 1},
#  ("'", 'just', 'like'): {'a': 1},
#  ("'", 'leave', 'out'): {'that': 1},
#  ("'", 'let', "'"): {'s': 1},
#  ("'", 'lives', 'a'): {'Hatter': 1, 'March': 1},
#  ("'", 'living', 'at'): {'the': 1},
#  ("'", 'll', 'all'): {'think': 1},
#  ("'", 'll', 'be'): {'a': 1,
#                      'asleep': 1,
#                      'in': 1,
#                      'judge': 1,
#                      'jury': 1,
#                      'no': 1,
#                      'sending': 1,
#                      'telling': 1,
#                      'when': 1},
#  ("'", 'll', 'come'): {'up': 1},
#  ("'", 'll', 'do'): {'next': 1, 'well': 1},
#  ("'", 'll', 'eat'): {'a': 1, 'it': 1},
#  ("'", 'll', 'feel'): {'it': 1},
#  ("'", 'll', 'fetch'): {'the': 1, 'things': 1},
#  ("'", 'll', 'get'): {'into': 1, 'me': 1, 'used': 1},
#  ("'", 'll', 'give'): {'him': 1, 'them': 1},
#  ("'", 'll', 'go'): {'round': 1},
#  ("'", 'll', 'have'): {'nothing': 1, 'you': 3},
#  ("'", 'll', 'just'): {'see': 1},
#  ("'", 'll', 'kick'): {'you': 1},
#  ("'", 'll', 'look'): {'first': 1},
#  ("'", 'll', 'make'): {'me': 1},
#  ("'", 'll', 'manage'): {'better': 1},
#  ("'", 'll', 'miss'): {'me': 1},
#  ("'", 'll', 'never'): {'do': 2, 'go': 1},
#  ("'", 'll', 'put'): {'a': 1},
#  ("'", 'll', 'remember'): {'her': 1},
#  ("'", 'll', 'see'): {'me': 1},
#  ("'", 'll', 'seem'): {',': 1, 'to': 1},
#  ("'", 'll', 'set'): {'Dinah': 1},
#  ("'", 'll', 'sit'): {'up': 1},
#  ("'", 'll', 'stay'): {'down': 2},
#  ("'", 'll', 'take'): {'no': 1},
#  ("'", 'll', 'tell'): {'him': 1, 'it': 1, 'you': 1},
#  ("'", 'll', 'think'): {'me': 1},
#  ("'", 'll', 'try'): {'and': 1, 'if': 1, 'the': 1},
#  ("'", 'll', 'understand'): {'why': 1},
#  ("'", 'll', 'write'): {'one': 1},
#  ("'", 'm', 'I'): {',': 1},
#  ("'", 'm', 'Mabel'): {',': 1},
#  ("'", 'm', 'NOT'): {'a': 2},
#  ("'", 'm', 'a'): {'--': 1,
#                    "--'": 1,
#                    'deal': 1,
#                    'hatter': 1,
#                    'little': 1,
#                    'poor': 3},
#  ("'", 'm', 'afraid'): {',': 2, ",'": 1, 'I': 4},
#  ("'", 'm', 'angry'): {'.': 1},
#  ("'", 'm', 'better'): {'now': 1},
#  ("'", 'm', 'certain'): {'!': 1},
#  ("'", 'm', 'doubtful'): {'about': 1},
#  ("'", 'm', 'getting'): {'tired': 1},
#  ("'", 'm', 'glad'): {'I': 1, 'they': 2},
#  ("'", 'm', 'going'): {'to': 1},
#  ("'", 'm', 'growing'): {".'": 1},
#  ("'", 'm', 'grown'): {'up': 1},
#  ("'", 'm', 'here'): {'!': 1},
#  ("'", 'm', 'mad'): {'.': 1, ".'": 1, "?'": 1},
#  ("'", 'm', 'never'): {'sure': 1},
#  ("'", 'm', 'not'): {'Ada': 1,
#                      'looking': 1,
#                      'myself': 1,
#                      'particular': 1,
#                      'the': 1,
#                      'used': 1},
#  ("'", 'm', 'on'): {'the': 2},
#  ("'", 'm', 'opening'): {'out': 1},
#  ("'", 'm', 'perfectly'): {'sure': 1},
#  ("'", 'm', 'pleased'): {',': 1},
#  ("'", 'm', 'quite'): {'tired': 1},
#  ("'", 'm', 'somebody'): {'else': 1},
#  ("'", 'm', 'sure'): {'I': 3, '_I_': 1, 'she': 1, 'those': 1},
#  ("'", 'm', 'talking'): {"!'": 1},
#  ("'", 'm', 'too'): {'stiff': 1},
#  ("'", 'm', 'very'): {'sorry': 1},
#  ("'", 'moral', ",'"): {'and': 1},
#  ("'", 'nine', 'the'): {'next': 1},
#  ("'", 'no', 'wise'): {'fish': 1},
#  ("'", 'not', 'in'): {'that': 1},
#  ("'", 'not', 'that'): {'it': 1},
#  ("'", 'now', 'I'): {"'": 1},
#  ("'", 'of', 'course'): {'you': 1},
#  ("'", 'on', 'and'): {'off': 1},
#  ("'", 'one', 'would'): {'hardly': 1},
#  ("'", 'only', ','): {'as': 1},
#  ("'", 'only', 'one'): {'doesn': 1},
#  ("'", 'or', 'I'): {"'": 2},
#  ("'", 'or', 'perhaps'): {'they': 1},
#  ("'", 'or', 'you'): {"'": 1, 'wouldn': 1},
#  ("'", 'poison', ",'"): {'it': 1, 'so': 1},
#  ("'", 're', 'a'): {'kind': 1, 'little': 1, 'serpent': 1, 'very': 1},
#  ("'", 're', 'about'): {"!'": 1},
#  ("'", 're', 'all'): {'mad': 1, 'over': 1},
#  ("'", 're', 'at'): {'!"': 1},
#  ("'", 're', 'both'): {'mad': 1},
#  ("'", 're', 'called'): {'lessons': 1},
#  ("'", 're', 'changed'): {',': 1},
#  ("'", 're', 'doing'): {"!'": 1, 'our': 1},
#  ("'", 're', 'done'): {'with': 1},
#  ("'", 're', 'dreadfully'): {'fond': 1},
#  ("'", 're', 'enough'): {'to': 1},
#  ("'", 're', 'falling'): {'through': 1},
#  ("'", 're', 'going'): {'to': 1},
#  ("'", 're', 'growing'): {'too': 1},
#  ("'", 're', 'like'): {".'": 1},
#  ("'", 're', 'looking'): {'for': 1},
#  ("'", 're', 'mad'): {".'": 1, "?'": 1},
#  ("'", 're', 'making'): {'such': 1},
#  ("'", 're', 'nervous'): {'or': 1},
#  ("'", 're', 'not'): {",'": 1},
#  ("'", 're', 'nothing'): {'but': 1},
#  ("'", 're', 'only'): {'a': 1},
#  ("'", 're', 'putting'): {'down': 1},
#  ("'", 're', 'so'): {'easily': 1},
#  ("'", 're', 'sure'): {'to': 2},
#  ("'", 're', 'talking'): {'about': 1},
#  ("'", 're', 'thinking'): {'about': 1},
#  ("'", 're', 'to'): {'go': 1},
#  ("'", 're', 'trying'): {'to': 1},
#  ("'", 're', 'wondering'): {'why': 1},
#  ("'", 're', 'wrong'): {'about': 1},
#  ("'", 'really', 'you'): {'are': 1},
#  ("'", 's', ','): {'and': 1},
#  ("'", 's', '--'): {'it': 1},
#  ("'", 's', "--'"): {'Pat': 1},
#  ("'", 's', 'Adventures'): {'in': 1},
#  ("'", 's', 'Bill'): {",'": 1},
#  ("'", 's', 'Croquet'): {'-': 1},
#  ("'", 's', 'Evidence'): {"'": 1},
#  ("'", 's', 'HIM'): {".'": 1},
#  ("'", 's', 'Latin'): {'Grammar': 1},
#  ("'", 's', 'PLENTY'): {'of': 1},
#  ("'", 's', 'Story'): {"'": 1},
#  ("'", 's', 'a'): {'Cheshire': 1,
#                    'French': 1,
#                    'fact': 1,
#                    'friend': 1,
#                    'great': 1,
#                    'large': 1,
#                    'mineral': 1,
#                    'porpoise': 1,
#                    'pun': 1,
#                    'set': 1,
#                    'vegetable': 1,
#                    'very': 2},
#  ("'", 's', 'about'): {'the': 1},
#  ("'", 's', 'absence'): {',': 1},
#  ("'", 's', 'all'): {".'": 1,
#                      'I': 1,
#                      'about': 1,
#                      'her': 1,
#                      'his': 1,
#                      'move': 1,
#                      'the': 1,
#                      'you': 1},
#  ("'", 's', 'always'): {'pepper': 1, 'six': 1, 'tea': 1},
#  ("'", 's', 'an'): {'arm': 2, 'atom': 2},
#  ("'", 's', 'angry'): {',': 1},
#  ("'", 's', 'any'): {'one': 1},
#  ("'", 's', 'argument'): {'was': 3},
#  ("'", 's', 'asleep'): {',': 1},
#  ("'", 's', 'at'): {'all': 1},
#  ("'", 's', 'bark'): {'sounded': 1},
#  ("'", 's', 'because'): {'it': 1},
#  ("'", 's', 'beginning'): {"!'": 1},
#  ("'", 's', 'begun'): {".'": 1},
#  ("'", 's', 'by'): {'far': 1},
#  ("'", 's', 'called'): {'a': 1},
#  ("'", 's', 'certainly'): {'too': 1},
#  ("'", 's', 'coming'): {'down': 1},
#  ("'", 's', 'conduct'): {'at': 1},
#  ("'", 's', 'cook'): {'.': 1},
#  ("'", 's', 'crown'): {'on': 1},
#  ("'", 's', 'curious'): {'today': 1},
#  ("'", 's', 'delay'): {'would': 1},
#  ("'", 's', 'different'): {'from': 1},
#  ("'", 's', 'done'): {".'": 1, 'by': 1},
#  ("'", 's', 'dream'): {'.': 1},
#  ("'", 's', 'ears'): {"--'": 1},
#  ("'", 's', 'elbow'): {'was': 1},
#  ("'", 's', 'enough'): {'about': 1, 'to': 1},
#  ("'", 's', 'feelings'): {'.': 1},
#  ("'", 's', 'first'): {'thought': 1},
#  ("'", 's', 'free'): {'at': 1},
#  ("'", 's', 'generally'): {'a': 1},
#  ("'", 's', 'getting'): {"!'": 1, 'late': 1},
#  ("'", 's', 'go'): {'on': 1},
#  ("'", 's', 'going'): {'on': 1},
#  ("'", 's', 'got'): {'a': 1, 'no': 1, 'the': 1, 'to': 1},
#  ("'", 's', 'great'): {'surprise': 1},
#  ("'", 's', 'half'): {'my': 1},
#  ("'", 's', 'hand'): {",'": 1},
#  ("'", 's', 'handwriting'): {"?'": 1},
#  ("'", 's', 'hardly'): {'enough': 1, 'room': 1, 'worth': 1},
#  ("'", 's', 'head'): {'.': 1, ':': 1, 'began': 1, 'with': 1},
#  ("'", 's', 'hear'): {'some': 1},
#  ("'", 's', 'heavy'): {'sobs': 1},
#  ("'", 's', 'hedgehog'): {'just': 1},
#  ("'", 's', 'high'): {'time': 1},
#  ("'", 's', 'in'): {'it': 1, 'prison': 1},
#  ("'", 's', 'it'): {",'": 1},
#  ("'", 's', 'knee'): {',': 1},
#  ("'", 's', 'laid'): {'for': 1},
#  ("'", 's', 'little'): {'white': 1},
#  ("'", 's', 'making'): {'personal': 1, 'such': 1},
#  ("'", 's', 'marked'): {'"': 1},
#  ("'", 's', 'more'): {',': 1, 'evidence': 1},
#  ("'", 's', 'murdering'): {'the': 1},
#  ("'", 's', 'no'): {'business': 1,
#                     'harm': 1,
#                     'meaning': 1,
#                     'name': 1,
#                     'pleasing': 1,
#                     'room': 1,
#                     'sort': 1,
#                     'such': 1,
#                     'use': 6},
#  ("'", 's', 'none'): {'of': 1},
#  ("'", 's', 'not'): {'a': 1, 'at': 1, 'mad': 1},
#  ("'", 's', 'nothing'): {'to': 1, 'written': 1},
#  ("'", 's', 'our'): {'cat': 1},
#  ("'", 's', 'over'): {"!'": 1},
#  ("'", 's', 'own'): {'feet': 1},
#  ("'", 's', 'pause'): {'.': 1},
#  ("'", 's', 'perfectly'): {'idiotic': 1},
#  ("'", 's', 'place'): {',': 1, 'for': 1},
#  ("'", 's', 'pleased'): {'.': 1, 'so': 1},
#  ("'", 's', 'quite'): {'enough': 1},
#  ("'", 's', 'rather'): {'curious': 1},
#  ("'", 's', 'really'): {'dreadful': 1},
#  ("'", 's', 'remark'): {'seemed': 1},
#  ("'", 's', 'right'): {"!'": 1, ',': 1},
#  ("'", 's', 'shoulder'): {',': 1, 'as': 1},
#  ("'", 's', 'shrill'): {'cries': 1},
#  ("'", 's', 'side'): {'as': 1},
#  ("'", 's', 'slate'): {'-': 1},
#  ("'", 's', 'so'): {'extremely': 1, 'useful': 1},
#  ("'", 's', 'such'): {'a': 2},
#  ("'", 's', 'sure'): {'to': 1},
#  ("'", 's', 'tail'): {';': 1},
#  ("'", 's', 'that'): {'in': 1},
#  ("'", 's', 'the'): {'Cheshire': 1,
#                      'Duchess': 1,
#                      'answer': 1,
#                      'arch': 1,
#                      'best': 1,
#                      'first': 2,
#                      'judge': 1,
#                      'jury': 2,
#                      'most': 2,
#                      'oldest': 1,
#                      'other': 1,
#                      'queerest': 1,
#                      'reason': 1,
#                      'same': 1,
#                      'stupidest': 1,
#                      'thing': 1},
#  ("'", 's', 'to'): {'go': 2},
#  ("'", 's', 'too'): {'bad': 1},
#  ("'", 's', 'treading'): {'on': 1},
#  ("'", 's', 'try'): {'Geography': 1, 'the': 1},
#  ("'", 's', 'under'): {'sentence': 1},
#  ("'", 's', 'very'): {'curious': 2,
#                       'easy': 1,
#                       'important': 1,
#                       'interesting': 1,
#                       'like': 1,
#                       'rude': 1},
#  ("'", 's', 'voice'): {';': 1, 'along': 1, 'died': 1, 'in': 1},
#  ("'", 's', 'why'): {'.': 1},
#  ("'", 's', 'worth'): {'a': 1},
#  ("'", 's', 'your'): {'name': 1},
#  ("'", 'said', 'Alice'): {',': 1},
#  ("'", 'shall', 'I'): {'NEVER': 1},
#  ("'", 'she', "'"): {'s': 1},
#  ("'", 'she', 'wants'): {'for': 1},
#  ("'", 'sit', 'down'): {',': 1},
#  ("'", 'so', 'I'): {'can': 1, 'should': 1},
#  ("'", 'so', 'now'): {'let': 1},
#  ("'", 'some', 'of'): {'the': 1},
#  ("'", 'stupid', ",'"): {'and': 1},
#  ("'", 'stupid', 'things'): {"!'": 1},
#  ("'", 't', '!'): {'YOU': 1},
#  ("'", 't', "!'"): {'interrupted': 1, 'said': 1, 'the': 2},
#  ("'", 't', "'"): {'thought': 1},
#  ("'", 't', ','): {'then': 1},
#  ("'", 't', ",'"): {'said': 4},
#  ("'", 't', 'FIT'): {'you': 1},
#  ("'", 't', 'a'): {'bird': 1, 'bit': 1, 'letter': 1, 'really': 1},
#  ("'", 't', 'afford'): {'to': 1},
#  ("'", 't', 'always'): {'growing': 1},
#  ("'", 't', 'answer'): {'either': 1},
#  ("'", 't', 'any'): {",'": 1},
#  ("'", 't', 'asleep'): {",'": 1},
#  ("'", 't', 'be'): {'Mabel': 1,
#                     'able': 1,
#                     'afraid': 1,

# %%
print( model.generate_text(100,"the next thing") )
# Out:
# the next thing is , to get into that beautiful garden -- how IS it to be true ): If she should push the matter on , What would become of you ? I gave her one , they gave him two , You gave us three or more ; They all returned from him to you , Though they were mine before . If I or she should chance to be Involved in this affair , He trusts to you to set them free , Exactly as we were . My notion was that you had been ( Before she had this

# %% [markdown]
# ## Visualizee

# %%
from nltk.corpus import gutenberg
import random

caroll_tokens = [t.lower() for t in gutenberg.words('carroll-alice.txt')]

window = 30
start = random.randint(0, len(caroll_tokens) - window)
small_tokens = caroll_tokens[start:start + window]

model2 = MarkovModel(order=3)
model2.train(small_tokens)

print("Start index:", start)
model2.visualize(probabilities=False)
# Out:
# Start index: 25588

# %% [markdown]
# Presented to
# Evan scherrer
# Sagar Bhandari
